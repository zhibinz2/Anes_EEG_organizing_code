# %% [markdown]
# # EEG student review and segment preparation
#
# This notebook provides a graphical workflow for reviewing BrainVision EEG recordings (`.vhdr`, `.eeg`, `.vmrk`). The original files are never modified.
#
# Run Steps 1–5 in order:
# 1. Select one or more `.vhdr` files and an output folder in Windows dialogs.
# 2. Load the helper functions.
# 3. Choose one queued recording and create an untouched master plus a 250 Hz, 0.5–50 Hz filtered copy.
# 4. Inspect all channels and annotations using the stacked Plotly average-reference display.
# 5. Use the GUI to standardize/insert annotations, rename channels, mark bad channels, confirm the selected range in Plotly, and save.
#
# **Important:** Step 4 shows the 250 Hz, 0.5–50 Hz filtered, average-referenced signal in physical units so you can select processing sections. Global z-scoring is applied only to the sections selected for final export. Unannotated time is unreviewed, not automatically clean.

# %%
# %pip install h5py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: h5py in c:\ProgramData\anaconda3\Lib\site-packages (3.16.0)
# Requirement already satisfied: numpy>=1.21.2 in c:\ProgramData\anaconda3\Lib\site-packages (from h5py) (2.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install mne
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mne in C:\Users\zhouz\AppData\Roaming\Python\Python314\site-packages (1.12.1)
# Requirement already satisfied: decorator>=5.1 in c:\ProgramData\anaconda3\Lib\site-packages (from mne) (5.3.1)
# Requirement already satisfied: jinja2>=3.1 in c:\ProgramData\anaconda3\Lib\site-packages (from mne) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in c:\ProgramData\anaconda3\Lib\site-packages (from mne) (0.5)
# Requirement already satisfied: matplotlib>=3.8 in c:\ProgramData\anaconda3\Lib\site-packages (from mne) (3.11.0)
# Requirement already satisfied: numpy<3,>=1.26 in c:\ProgramData\anaconda3\Lib\site-packages (from mne) (2.4.6)
# Requirement already satisfied: packaging in c:\ProgramData\anaconda3\Lib\site-packages (from mne) (26.0)
# Requirement already satisfied: pooch>=1.5 in C:\Users\zhouz\AppData\Roaming\Python\Python314\site-packages (from mne) (1.9.0)
# Requirement already satisfied: scipy>=1.13 in c:\ProgramData\anaconda3\Lib\site-packages (from mne) (1.18.0)
# Requirement already satisfied: tqdm>=4.66 in c:\ProgramData\anaconda3\Lib\site-packages (from mne) (4.68.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\ProgramData\anaconda3\Lib\site-packages (from jinja2>=3.1->mne) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\ProgramData\anaconda3\Lib\site-packages (from matplotlib>=3.8->mne) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\ProgramData\anaconda3\Lib\site-packages (from matplotlib>=3.8->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\ProgramData\anaconda3\Lib\site-packages (from matplotlib>=3.8->mne) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\ProgramData\anaconda3\Lib\site-packages (from matplotlib>=3.8->mne) (1.4.9)
# Requirement already satisfied: pillow>=9 in c:\ProgramData\anaconda3\Lib\site-packages (from matplotlib>=3.8->mne) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\ProgramData\anaconda3\Lib\site-packages (from matplotlib>=3.8->mne) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\ProgramData\anaconda3\Lib\site-packages (from matplotlib>=3.8->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\ProgramData\anaconda3\Lib\site-packages (from pooch>=1.5->mne) (4.9.4)
# Requirement already satisfied: requests>=2.19.0 in c:\ProgramData\anaconda3\Lib\site-packages (from pooch>=1.5->mne) (2.34.2)
# Requirement already satisfied: six>=1.5 in c:\ProgramData\anaconda3\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.8->mne) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\ProgramData\anaconda3\Lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2026.6.17)
# Requirement already satisfied: colorama in c:\ProgramData\anaconda3\Lib\site-packages (from tqdm>=4.66->mne) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Setup: install missing packages if needed.
# The technical lead should run this once before the student begins.
import importlib.util
import subprocess
import sys

required = {
    "numpy": "numpy",
    "plotly": "plotly",
    "scipy": "scipy",
    "mne": "mne",
    "PyQt6": "PyQt6",
}
missing = [package for module, package in required.items() if importlib.util.find_spec(module) is None]
if missing:
    print("Installing missing packages:", missing)
    subprocess.check_call([sys.executable, "-m", "pip", "install", *missing])
    print("Installation complete. Restart the notebook kernel, then run this cell again.")
else:
    get_ipython().run_line_magic("gui", "qt5")
    print("GUI packages are ready.")
# Out:
# Cannot switch Qt versions for this session; you must use qt6.
# GUI packages are ready.

# %% [markdown]
# ## 1. select patient

# %%
# Step 1: select patient recordings and the review output folder.
# Running this cell opens normal Windows selection dialogs.

from pathlib import Path
from PyQt6.QtWidgets import QApplication, QFileDialog

_app = QApplication.instance() or QApplication([])
VHDR_FILES, _ = QFileDialog.getOpenFileNames(
    None,
    "Select one or more BrainVision EEG header files",
    "",
    "BrainVision header files (*.vhdr)",
)
if not VHDR_FILES:
    raise RuntimeError("No .vhdr files were selected.")

EXPORT_FOLDER = QFileDialog.getExistingDirectory(
    None,
    "Choose the folder where reviewed data will be saved",
)
if not EXPORT_FOLDER:
    raise RuntimeError("No output folder was selected.")

print(f"Selected {len(VHDR_FILES)} recording(s):")
for number, path in enumerate(VHDR_FILES, start=1):
    print(f"  {number}. {Path(path).name}")
print("Review output folder:", EXPORT_FOLDER)
# Out:
# Selected 1 recording(s):
#   1. 20260612_test.vhdr
# Review output folder: C:/Users/zhouz/Documents/LiveAmp8/Reorganized_liveamp8data

# %% [markdown]
# ## 2. Functions

# %%
# Step 2: functions to load, plot, zoom, and export.

from pathlib import Path
import csv
import json
import math
import numpy as np
import plotly.graph_objects as go
from scipy.io import savemat


def _parse_key_value_file(path):
    sections = {}
    current = None
    with open(path, "r", encoding="utf-8", errors="replace") as f:
        for raw_line in f:
            line = raw_line.strip()
            if not line or line.startswith(";"):
                continue
            if line.startswith("[") and line.endswith("]"):
                current = line[1:-1].strip().lower()
                sections[current] = {}
                continue
            if current is None or "=" not in line:
                continue
            key, value = line.split("=", 1)
            sections[current][key.strip()] = value.strip()
    return sections


def load_brainvision(vhdr_file):
    vhdr_path = Path(vhdr_file)
    folder = vhdr_path.parent
    header = _parse_key_value_file(vhdr_path)
    common = header.get("common infos", {})
    binary = header.get("binary infos", {})
    channels = header.get("channel infos", {})

    data_file = common["DataFile"]
    data_format = common.get("DataFormat", "").upper()
    orientation = common.get("DataOrientation", "").upper()
    n_channels = int(common["NumberOfChannels"])
    srate = 1_000_000 / float(common["SamplingInterval"])
    binary_format = binary.get("BinaryFormat", "").upper()

    if data_format != "BINARY":
        raise ValueError(f"This beginner notebook expects DataFormat=BINARY, found {data_format!r}.")
    if orientation != "MULTIPLEXED":
        raise ValueError(f"This notebook expects DataOrientation=MULTIPLEXED, found {orientation!r}.")

    dtype_map = {
        "IEEE_FLOAT_32": np.float32,
        "INT_16": np.int16,
        "UINT_16": np.uint16,
    }
    if binary_format not in dtype_map:
        raise ValueError(f"Unsupported BinaryFormat: {binary_format!r}")
    dtype = dtype_map[binary_format]

    labels = []
    scales = []
    for ch in range(1, n_channels + 1):
        entry = channels.get(f"Ch{ch}", f"Ch {ch},,1,")
        parts = entry.split(",")
        labels.append(parts[0].strip() or f"Ch {ch}")
        scale = float(parts[2]) if len(parts) >= 3 and parts[2].strip() else 1.0
        scales.append(scale)

    eeg_path = folder / data_file
    raw = np.fromfile(eeg_path, dtype=dtype)
    if raw.size % n_channels != 0:
        raise ValueError("The .eeg file length is not divisible by the number of channels.")
    n_samples = raw.size // n_channels
    data = raw.reshape(n_samples, n_channels).T.astype(float)
    data *= np.asarray(scales)[:, None]

    marker_path = folder / f"{vhdr_path.stem}.vmrk"
    markers = []
    if marker_path.exists():
        marker_info = _parse_key_value_file(marker_path).get("marker infos", {})
        for key, value in marker_info.items():
            parts = value.split(",")
            if len(parts) >= 3:
                marker_type = parts[0].strip()
                label = parts[1].strip().replace(r"\1", ",")
                sample = int(float(parts[2]))
                if marker_type.lower() == "comment" and label:
                    markers.append({"label": label, "sample": sample, "time_sec": (sample - 1) / srate})

    return {
        "vhdr_file": str(vhdr_path),
        "eeg_file": str(eeg_path),
        "marker_file": str(marker_path),
        "data": data,
        "labels": labels,
        "srate": srate,
        "n_samples": n_samples,
        "duration_sec": n_samples / srate,
        "markers": markers,
    }


def _downsample_indices(n_samples, max_points):
    step = max(1, math.ceil(n_samples / max_points))
    return np.arange(0, n_samples, step)


def _reference_for_view(y, plot_mode):
    if plot_mode == "raw":
        return y, "Amplitude"

    if plot_mode == "average_reference":
        return y - np.nanmean(y, axis=0, keepdims=True), "Average-referenced amplitude"
    else:
        raise ValueError("plot_mode must be 'raw' or 'average_reference'.")


def plot_raw(eeg, start_sec=None, end_sec=None, channels="all", max_points=6000, plot_mode="average_reference"):
    data = eeg["data"]
    labels = eeg["labels"]
    srate = eeg["srate"]
    if start_sec is None:
        start_sec = 0
    if end_sec is None:
        end_sec = eeg["duration_sec"]
    start_sample = max(0, int(round(start_sec * srate)))
    end_sample = min(eeg["n_samples"], int(round(end_sec * srate)))

    if channels == "all":
        channel_indices = list(range(data.shape[0]))
    else:
        channel_indices = [labels.index(ch) if isinstance(ch, str) else int(ch) for ch in channels]

    sample_indices = start_sample + _downsample_indices(end_sample - start_sample, max_points)
    t = sample_indices / srate / 60.0
    y_raw = data[np.ix_(channel_indices, sample_indices)]
    y, ylabel = _reference_for_view(y_raw, plot_mode)

    robust = np.nanpercentile(np.abs(y - np.nanmedian(y)), 95)
    spacing = robust * 4 if np.isfinite(robust) and robust > 0 else 1.0
    offsets = np.arange(len(channel_indices))[::-1] * spacing

    fig = go.Figure()
    for row, ch in enumerate(channel_indices):
        fig.add_trace(go.Scattergl(
            x=t,
            y=y[row] + offsets[row],
            mode="lines",
            name=labels[ch],
            line={"width": 1},
        ))

    top = float(np.nanmax(y + offsets[:, None]))
    bottom = float(np.nanmin(y + offsets[:, None]))
    height = top - bottom if top > bottom else 1.0
    label_y = top + 0.05 * height

    for marker in eeg["markers"]:
        x = marker["time_sec"] / 60.0
        if start_sec <= marker["time_sec"] <= end_sec:
            fig.add_vline(x=x, line_color="red", line_dash="dash", opacity=0.65)
            fig.add_annotation(
                x=x,
                y=label_y,
                text=marker["label"],
                showarrow=False,
                textangle=-45,
                font={"color": "red", "size": 11},
                yanchor="bottom",
            )

    fig.update_layout(
        title=f"EEG with marker labels ({plot_mode})",
        xaxis_title="Time (minutes)",
        yaxis={"title": ylabel, "tickmode": "array", "tickvals": offsets, "ticktext": [labels[ch] for ch in channel_indices]},
        hovermode="x unified",
        height=max(520, 90 * len(channel_indices)),
        margin={"l": 80, "r": 30, "t": 100, "b": 50},
    )
    fig.update_yaxes(range=[bottom - 0.05 * height, top + 0.25 * height])
    fig.show()


def export_segment(eeg, start_sec, end_sec, segment_name, export_folder=EXPORT_FOLDER):
    export_path = Path(export_folder)
    export_path.mkdir(parents=True, exist_ok=True)

    srate = eeg["srate"]
    start_sample = max(0, int(round(start_sec * srate)))
    end_sample = min(eeg["n_samples"], int(round(end_sec * srate)))
    if end_sample <= start_sample:
        raise ValueError("End time must be after start time.")

    data_segment = eeg["data"][:, start_sample:end_sample]
    time_sec = np.arange(start_sample, end_sample) / srate
    segment_markers = [m for m in eeg["markers"] if start_sec <= m["time_sec"] <= end_sec]

    safe_name = "".join(c if c.isalnum() or c in "-_" else "_" for c in segment_name).strip("_")
    base = export_path / safe_name

    with open(base.with_suffix(".csv"), "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["time_sec", *eeg["labels"]])
        for i in range(data_segment.shape[1]):
            writer.writerow([time_sec[i], *data_segment[:, i]])

    np.savez_compressed(
        base.with_suffix(".npz"),
        data=data_segment,
        time_sec=time_sec,
        srate=srate,
        channel_labels=np.array(eeg["labels"], dtype=object),
        markers=np.array(segment_markers, dtype=object),
    )

    savemat(base.with_suffix(".mat"), {
        "data": data_segment,
        "time_sec": time_sec,
        "srate": srate,
        "channel_labels": np.array(eeg["labels"], dtype=object),
        "marker_labels": np.array([m["label"] for m in segment_markers], dtype=object),
        "marker_times_sec": np.array([m["time_sec"] for m in segment_markers]),
    })

    metadata = {
        "source_vhdr_file": eeg["vhdr_file"],
        "source_eeg_file": eeg["eeg_file"],
        "start_sec": start_sec,
        "end_sec": end_sec,
        "start_sample": start_sample,
        "end_sample_exclusive": end_sample,
        "srate": srate,
        "channel_labels": eeg["labels"],
        "markers_in_segment": segment_markers,
        "files": [str(base.with_suffix(ext)) for ext in [".csv", ".npz", ".mat", ".json"]],
    }
    with open(base.with_suffix(".json"), "w", encoding="utf-8") as f:
        json.dump(metadata, f, indent=2)

    print("Saved segment files:")
    print(base.with_suffix(".csv"))
    print(base.with_suffix(".npz"))
    print(base.with_suffix(".mat"))
    print(base.with_suffix(".json"))

# ---------- Beginner GUI review helpers ----------

import hashlib
import re
from datetime import datetime, timezone

import mne
from PyQt6.QtCore import Qt
from PyQt6.QtWidgets import (
    QApplication,
    QAbstractItemView,
    QCheckBox,
    QComboBox,
    QDialog,
    QDialogButtonBox,
    QDoubleSpinBox,
    QFileDialog,
    QFormLayout,
    QGroupBox,
    QHBoxLayout,
    QInputDialog,
    QLabel,
    QLineEdit,
    QListWidget,
    QMessageBox,
    QPushButton,
    QTableWidget,
    QTableWidgetItem,
    QVBoxLayout,
)


STANDARD_LABELS = [
    "phase_preop",
    "phase_induction",
    "phase_maintenance",
    "phase_emergence",
    "phase_postop",
    "propofol_drip",
    "sevoflurane",
    "lidocaine_bolus",
    "propofol_bolus",
    "ketamine_bolus",
    "midazolam_bolus",
    "LOC",
    "Intubation",
    "Incision",
    "fentanyl_bolus",
    "morphine_bolus",
    "hydromorphone_bolus",
    "dexmedetomidine_bolus",
    "dexmedetomidine_bolus_10",
    "dexmedetomidine_bolus_20",
    "dexmedetomidine_bolus_40",
    "dexmedetomidine_drip",
    "lidocaine_bolus",
    "rocuronium_bolus",
    "Loss_of_responsiveness",
    "Return_of_responsiveness",
    "extubation",
    "ROC",
    "close",
    "BAD_eye_blink",
    "BAD_ECG",
    "BAD_movement",
    "BAD_electrocautery",
    "BAD_electrode_pop",
    "BAD_flat_channel",
    "BAD_line_noise",
    "BAD_other",
    "SSAEP40_start",
    "SSAEP40_stop",
    "Oddball_start",
    "Oddball_stop",
    "UNMAPPED_review_needed",
]

TARGET_SAMPLING_RATE_HZ = 250.0


def _qt_app():
    """Return the existing Qt application, or create one."""
    return QApplication.instance() or QApplication([])


def choose_brainvision_files_and_output():
    """Open native Windows dialogs for source files and output folder."""
    _qt_app()
    files, _ = QFileDialog.getOpenFileNames(
        None,
        "Select one or more BrainVision EEG header files",
        "",
        "BrainVision header files (*.vhdr)",
    )
    if not files:
        raise RuntimeError("No .vhdr files were selected.")

    output = QFileDialog.getExistingDirectory(
        None,
        "Choose the folder where reviewed data will be saved",
    )
    if not output:
        raise RuntimeError("No output folder was selected.")
    return [str(Path(path)) for path in files], str(Path(output))


def _copy_annotations(annotations):
    return mne.Annotations(
        onset=annotations.onset.copy(),
        duration=annotations.duration.copy(),
        description=annotations.description.copy(),
        orig_time=annotations.orig_time,
        ch_names=list(annotations.ch_names),
    )


def prepare_gui_recording(vhdr_files):
    """Choose one queued file and create master, filtered, and display copies."""
    _qt_app()
    names = [Path(path).name for path in vhdr_files]
    chosen, accepted = QInputDialog.getItem(
        None,
        "Choose recording",
        "Recording to review:",
        names,
        0,
        False,
    )
    if not accepted:
        raise RuntimeError("Recording selection was cancelled.")

    source = Path(vhdr_files[names.index(chosen)])
    master = mne.io.read_raw_brainvision(source, preload=True, verbose="ERROR")
    if master.info["sfreq"] < TARGET_SAMPLING_RATE_HZ:
        raise ValueError(
            f"Source sampling frequency must be at least {TARGET_SAMPLING_RATE_HZ:g} Hz for downsampling."
        )

    eeg_picks = mne.pick_types(master.info, eeg=True, exclude=[])
    if len(eeg_picks) == 0:
        raise ValueError("No channels are typed as EEG.")

    filtered = master.copy()
    if filtered.info["sfreq"] > TARGET_SAMPLING_RATE_HZ:
        filtered.resample(
            sfreq=TARGET_SAMPLING_RATE_HZ,
            npad="auto",
            verbose="ERROR",
        )
    filtered.filter(
        l_freq=0.5,
        h_freq=50.0,
        picks=eeg_picks,
        method="fir",
        phase="zero",
        fir_design="firwin",
        skip_by_annotation=("edge", "bad_acq_skip"),
        verbose="ERROR",
    )

    # Reference with every EEG channel, including any channels already marked bad.
    original_bads = list(filtered.info["bads"])
    filtered.info["bads"] = []
    filtered.set_eeg_reference(ref_channels="average", projection=False, verbose="ERROR")
    filtered.info["bads"] = original_bads

    display_raw = filtered.copy()

    return {
        "source": source,
        "master": master,
        "filtered": filtered,
        "display": display_raw,
        "eeg_picks": list(eeg_picks),
        "original_channel_names": list(master.ch_names),
        "label_audit": [],
        "channel_audit": [],
    }


def _remove_vocab_placeholders(raw, placeholders):
    keep = []
    for index, (onset, duration, description) in enumerate(
        zip(raw.annotations.onset, raw.annotations.duration, raw.annotations.description)
    ):
        is_placeholder = (
            description in placeholders
            and abs(float(onset)) < 1e-12
            and abs(float(duration)) < 1e-12
        )
        if not is_placeholder:
            keep.append(index)
    raw.set_annotations(raw.annotations[keep] if keep else mne.Annotations([], [], []))


def sync_display_review_to_master(review):
    """Copy annotations and globally bad channels from display to all copies."""
    display_raw = review["display"]
    master = review["master"]
    filtered = review["filtered"]

    bads = list(display_raw.info["bads"])
    annotations = _copy_annotations(display_raw.annotations)
    for raw in (master, filtered):
        raw.info["bads"] = bads
        raw.set_annotations(_copy_annotations(annotations))


def open_interactive_review_viewer(review, start_sec=0.0, duration_sec=30.0):
    """Open the MNE Qt viewer and synchronize edits when it closes."""
    display_raw = review["display"]
    existing = set(str(value) for value in display_raw.annotations.description)
    placeholders = [label for label in STANDARD_LABELS if label not in existing]
    for label in placeholders:
        display_raw.annotations.append(0.0, 0.0, label)

    mne.viz.set_browser_backend("qt")
    display_raw.plot(
        start=max(0.0, float(start_sec)),
        duration=max(1.0, float(duration_sec)),
        n_channels=len(display_raw.ch_names),
        scalings={"eeg": 40e-6},
        remove_dc=False,
        block=True,
        show=True,
        title=(
            "250 Hz, 0.5–50 Hz average-referenced EEG | "
            "Click channel=bad | Press A=annotations"
        ),
    )

    _remove_vocab_placeholders(display_raw, set(placeholders))
    sync_display_review_to_master(review)


class ReviewMetadataDialog(QDialog):
    """GUI for standardized labels, channel names, and annotation insertion."""

    def __init__(self, review, parent=None):
        super().__init__(parent)
        self.review = review
        self.raw = review["master"]
        self.setWindowTitle("Standardize EEG metadata and annotations")
        self.resize(1150, 800)

        instructions = QLabel(
            "Rename channels in the table. For every annotation, choose a "
            "standard label or keep the original. Check Delete only for an "
            "incorrect annotation. New annotations may apply to all channels "
            "or selected channels."
        )
        instructions.setWordWrap(True)

        channels_box = QGroupBox("Channel labels and globally bad channels")
        channels_layout = QVBoxLayout(channels_box)
        self.channel_table = QTableWidget(len(self.raw.ch_names), 4)
        self.channel_table.setHorizontalHeaderLabels(
            ["Original channel", "New channel label", "Globally bad", "Reason"]
        )
        for row, channel in enumerate(self.raw.ch_names):
            original = QTableWidgetItem(channel)
            original.setFlags(original.flags() & ~Qt.ItemFlag.ItemIsEditable)
            self.channel_table.setItem(row, 0, original)
            self.channel_table.setItem(row, 1, QTableWidgetItem(channel))
            bad = QCheckBox()
            bad.setChecked(channel in self.raw.info["bads"])
            self.channel_table.setCellWidget(row, 2, bad)
            self.channel_table.setItem(row, 3, QTableWidgetItem(""))
        self.channel_table.resizeColumnsToContents()
        channels_layout.addWidget(self.channel_table)

        annotations_box = QGroupBox("Existing annotations")
        annotations_layout = QVBoxLayout(annotations_box)
        self.annotation_table = QTableWidget(len(self.raw.annotations), 7)
        self.annotation_table.setHorizontalHeaderLabels(
            [
                "Onset (sec)",
                "Duration (sec)",
                "Original label",
                "Standard label",
                "Channels",
                "Delete",
                "Reviewer note",
            ]
        )
        for row, (onset, duration, description, channels) in enumerate(
            zip(
                self.raw.annotations.onset,
                self.raw.annotations.duration,
                self.raw.annotations.description,
                self.raw.annotations.ch_names,
            )
        ):
            for column, value in enumerate(
                [
                    f"{float(onset):.3f}",
                    f"{float(duration):.3f}",
                    str(description),
                ]
            ):
                item = QTableWidgetItem(value)
                item.setFlags(item.flags() & ~Qt.ItemFlag.ItemIsEditable)
                self.annotation_table.setItem(row, column, item)
            label = QComboBox()
            label.addItems(["KEEP_ORIGINAL"] + STANDARD_LABELS)
            if str(description) in STANDARD_LABELS:
                label.setCurrentText(str(description))
            self.annotation_table.setCellWidget(row, 3, label)
            channel_text = ",".join(channels) if channels else "all"
            channel_item = QTableWidgetItem(channel_text)
            channel_item.setFlags(channel_item.flags() & ~Qt.ItemFlag.ItemIsEditable)
            self.annotation_table.setItem(row, 4, channel_item)
            self.annotation_table.setCellWidget(row, 5, QCheckBox())
            self.annotation_table.setItem(row, 6, QTableWidgetItem(""))
        self.annotation_table.resizeColumnsToContents()
        annotations_layout.addWidget(self.annotation_table)

        add_box = QGroupBox("Insert a new annotation")
        add_layout = QFormLayout(add_box)
        self.add_onset = QDoubleSpinBox()
        self.add_onset.setRange(0.0, float(self.raw.times[-1]))
        self.add_onset.setDecimals(3)
        self.add_duration = QDoubleSpinBox()
        self.add_duration.setRange(0.001, float(self.raw.times[-1]))
        self.add_duration.setDecimals(3)
        self.add_duration.setValue(1.0)
        self.add_label = QComboBox()
        self.add_label.addItems(STANDARD_LABELS)
        self.add_channels = QListWidget()
        self.add_channels.setSelectionMode(
            QAbstractItemView.SelectionMode.ExtendedSelection
        )
        self.add_channels.addItem("ALL")
        self.add_channels.addItems(self.raw.ch_names)
        self.add_channels.item(0).setSelected(True)
        self.add_button = QPushButton("Add annotation to table")
        self.add_button.clicked.connect(self._add_annotation_row)
        add_layout.addRow("Onset:", self.add_onset)
        add_layout.addRow("Duration:", self.add_duration)
        add_layout.addRow("Standard label:", self.add_label)
        add_layout.addRow("Affected channels:", self.add_channels)
        add_layout.addRow("", self.add_button)

        zoom_box = QGroupBox("Optional range to reopen in the EEG viewer")
        zoom_layout = QFormLayout(zoom_box)
        self.zoom_start = QDoubleSpinBox()
        self.zoom_start.setRange(0.0, float(self.raw.times[-1]))
        self.zoom_start.setDecimals(3)
        self.zoom_end = QDoubleSpinBox()
        self.zoom_end.setRange(0.001, float(self.raw.times[-1]))
        self.zoom_end.setDecimals(3)
        self.zoom_end.setValue(min(120.0, float(self.raw.times[-1])))
        zoom_layout.addRow("Start:", self.zoom_start)
        zoom_layout.addRow("End:", self.zoom_end)

        buttons = QDialogButtonBox(
            QDialogButtonBox.StandardButton.Apply
            | QDialogButtonBox.StandardButton.Cancel
        )
        buttons.button(QDialogButtonBox.StandardButton.Apply).clicked.connect(
            self._validate_and_accept
        )
        buttons.rejected.connect(self.reject)

        bottom = QHBoxLayout()
        bottom.addWidget(add_box, 2)
        bottom.addWidget(zoom_box, 1)

        layout = QVBoxLayout(self)
        layout.addWidget(instructions)
        layout.addWidget(channels_box, 1)
        layout.addWidget(annotations_box, 2)
        layout.addLayout(bottom)
        layout.addWidget(buttons)

    def _add_annotation_row(self):
        selected = [item.text() for item in self.add_channels.selectedItems()]
        if not selected:
            QMessageBox.warning(self, "Missing channels", "Select ALL or channels.")
            return
        onset = float(self.add_onset.value())
        duration = float(self.add_duration.value())
        if onset + duration > self.raw.times[-1] + 1 / self.raw.info["sfreq"]:
            QMessageBox.warning(
                self, "Invalid interval", "The interval extends past the recording."
            )
            return

        row = self.annotation_table.rowCount()
        self.annotation_table.insertRow(row)
        values = [
            f"{onset:.3f}",
            f"{duration:.3f}",
            "(new annotation)",
        ]
        for column, value in enumerate(values):
            item = QTableWidgetItem(value)
            item.setFlags(item.flags() & ~Qt.ItemFlag.ItemIsEditable)
            self.annotation_table.setItem(row, column, item)
        label = QComboBox()
        label.addItems(STANDARD_LABELS)
        label.setCurrentText(self.add_label.currentText())
        self.annotation_table.setCellWidget(row, 3, label)
        channel_text = "all" if "ALL" in selected else ",".join(selected)
        channel_item = QTableWidgetItem(channel_text)
        channel_item.setFlags(channel_item.flags() & ~Qt.ItemFlag.ItemIsEditable)
        self.annotation_table.setItem(row, 4, channel_item)
        self.annotation_table.setCellWidget(row, 5, QCheckBox())
        self.annotation_table.setItem(row, 6, QTableWidgetItem("manually inserted"))

    def _validate_and_accept(self):
        new_names = [
            self.channel_table.item(row, 1).text().strip()
            for row in range(self.channel_table.rowCount())
        ]
        if any(not value for value in new_names):
            QMessageBox.warning(self, "Invalid channel label", "Channel labels cannot be blank.")
            return
        if len(set(new_names)) != len(new_names):
            QMessageBox.warning(self, "Duplicate channel label", "Channel labels must be unique.")
            return
        if self.zoom_end.value() <= self.zoom_start.value():
            QMessageBox.warning(self, "Invalid range", "Zoom end must be after zoom start.")
            return
        self.accept()

    def apply_changes(self):
        old_names = list(self.raw.ch_names)
        new_names = [
            self.channel_table.item(row, 1).text().strip()
            for row in range(self.channel_table.rowCount())
        ]
        rename_map = {
            old: new for old, new in zip(old_names, new_names) if old != new
        }
        bad_old_names = [
            old_names[row]
            for row in range(len(old_names))
            if self.channel_table.cellWidget(row, 2).isChecked()
        ]
        reasons = {
            old_names[row]: self.channel_table.item(row, 3).text().strip()
            for row in range(len(old_names))
            if self.channel_table.item(row, 3).text().strip()
        }

        onset = []
        duration = []
        description = []
        ch_names = []
        label_audit = []
        for row in range(self.annotation_table.rowCount()):
            if self.annotation_table.cellWidget(row, 5).isChecked():
                continue
            row_onset = float(self.annotation_table.item(row, 0).text())
            row_duration = float(self.annotation_table.item(row, 1).text())
            raw_label = self.annotation_table.item(row, 2).text()
            selected_label = self.annotation_table.cellWidget(row, 3).currentText()
            standard_label = (
                raw_label if selected_label == "KEEP_ORIGINAL" else selected_label
            )
            channel_text = self.annotation_table.item(row, 4).text()
            old_channels = [] if channel_text == "all" else channel_text.split(",")
            mapped_channels = [rename_map.get(value, value) for value in old_channels]
            note = self.annotation_table.item(row, 6).text().strip()

            onset.append(row_onset)
            duration.append(row_duration)
            description.append(standard_label)
            ch_names.append(mapped_channels)
            label_audit.append(
                {
                    "onset_sec": row_onset,
                    "duration_sec": row_duration,
                    "raw_label": raw_label,
                    "standard_label": standard_label,
                    "reviewer_note": note,
                }
            )

        for raw in (
            self.review["master"],
            self.review["filtered"],
            self.review["display"],
        ):
            if rename_map:
                raw.rename_channels(rename_map)
            raw.info["bads"] = [rename_map.get(name, name) for name in bad_old_names]
            raw.set_annotations(
                mne.Annotations(
                    onset=onset,
                    duration=duration,
                    description=description,
                    orig_time=raw.annotations.orig_time,
                    ch_names=ch_names,
                )
            )

        self.review["label_audit"] = label_audit
        self.review["channel_audit"] = [
            {
                "original_channel": old,
                "standard_channel": rename_map.get(old, old),
                "globally_bad": old in bad_old_names,
                "reason": reasons.get(old, ""),
            }
            for old in old_names
        ]
        return float(self.zoom_start.value()), float(self.zoom_end.value())


def open_metadata_review_gui(review):
    _qt_app()
    dialog = ReviewMetadataDialog(review)
    if dialog.exec() != QDialog.DialogCode.Accepted:
        raise RuntimeError("Metadata review was cancelled; nothing was changed.")
    return dialog.apply_changes()


def sync_legacy_eeg_dictionary(review, eeg):
    """Keep the notebook's later Plotly/spectrogram cells compatible."""
    raw = review["master"]
    eeg["labels"] = list(raw.ch_names)
    eeg["markers"] = [
        {
            "label": str(description),
            "sample": int(round(float(onset) * raw.info["sfreq"])) + 1,
            "time_sec": float(onset),
            "duration_sec": float(duration),
            "channels": list(channels),
        }
        for onset, duration, description, channels in zip(
            raw.annotations.onset,
            raw.annotations.duration,
            raw.annotations.description,
            raw.annotations.ch_names,
        )
    ]
    return eeg


class SaveReviewDialog(QDialog):
    def __init__(self, parent=None):
        super().__init__(parent)
        self.setWindowTitle("Save reviewed EEG")
        self.resize(520, 330)

        explanation = QLabel(
            "Use deidentified identifiers only. The source BrainVision files "
            "will not be changed. A new versioned folder will be created."
        )
        explanation.setWordWrap(True)

        self.participant = QLineEdit("L000")
        self.run = QLineEdit("run-01")
        self.reviewer = QLineEdit()
        self.context = QComboBox()
        self.context.addItems(
            ["preop1", "preop2", "or1", "or2", "or3", "or4"]
        )

        form = QFormLayout()
        form.addRow("Participant:", self.participant)
        form.addRow("Recording:", self.run)
        form.addRow("Reviewer initials/ID:", self.reviewer)
        form.addRow("Processing sections:", QLabel("Defined by the Step 4 selections"))

        buttons = QDialogButtonBox(
            QDialogButtonBox.StandardButton.Save
            | QDialogButtonBox.StandardButton.Cancel
        )
        buttons.button(QDialogButtonBox.StandardButton.Save).clicked.connect(
            self._validate_and_accept
        )
        buttons.rejected.connect(self.reject)

        layout = QVBoxLayout(self)
        layout.addWidget(explanation)
        layout.addLayout(form)
        layout.addWidget(buttons)

    def _validate_and_accept(self):
        participant = self.participant.text().strip()
        if not re.fullmatch(r"L[0-9]{3,}", participant, flags=re.IGNORECASE):
            QMessageBox.warning(
                self,
                "Invalid participant",
                "Use a deidentified participant ID such as L000 or L0123.",
            )
            return
        run = self.run.text().strip()
        if not re.fullmatch(r"run-[A-Za-z0-9]+", run):
            QMessageBox.warning(
                self,
                "Invalid recording",
                "Use a recording value such as run-01.",
            )
            return
        if not re.fullmatch(r"[A-Za-z0-9_-]{1,20}", self.reviewer.text().strip()):
            QMessageBox.warning(
                self,
                "Invalid reviewer",
                "Enter 1–20 initials/ID characters without spaces.",
            )
            return
        self.accept()

    def values(self):
        return {
            "participant": self.participant.text().strip(),
            "run": self.run.text().strip(),
            "reviewer": self.reviewer.text().strip(),
            "context": self.context.currentText(),
        }


def _sha256(path):
    digest = hashlib.sha256()
    with Path(path).open("rb") as handle:
        for block in iter(lambda: handle.read(1024 * 1024), b""):
            digest.update(block)
    return digest.hexdigest()


def _write_tsv(path, rows, columns):
    with Path(path).open("w", newline="", encoding="utf-8") as handle:
        writer = csv.DictWriter(handle, fieldnames=columns, delimiter="\t")
        writer.writeheader()
        for row in rows:
            writer.writerow({column: row.get(column, "") for column in columns})


def save_review_gui(review, export_folder):
    """Collect deidentified metadata and save a versioned review bundle."""
    _qt_app()
    dialog = SaveReviewDialog()
    if dialog.exec() != QDialog.DialogCode.Accepted:
        raise RuntimeError("Save was cancelled.")
    values = dialog.values()

    participant = values["participant"]
    run = values["run"]
    reviewer = values["reviewer"]
    stamp = datetime.now(timezone.utc).strftime("%Y%m%dT%H%M%SZ")
    context = values["context"]
    base = f"{participant}_task-anesthesia_acq-{context}_{run}"
    output = (
        Path(export_folder)
        / participant
        / "eeg"
        / f"review-{stamp}"
    )
    output.mkdir(parents=True, exist_ok=False)

    master = review["master"]
    processed = review["filtered"].copy().load_data()
    processed.set_annotations(master.annotations.copy())
    processed.info["bads"] = list(master.info["bads"])

    reviewed_path = output / f"{base}_desc-filteredAverageRef_raw.fif"
    processed.save(reviewed_path, overwrite=False, verbose="ERROR")

    annotation_rows = []
    for onset, duration, description, channels in zip(
        master.annotations.onset,
        master.annotations.duration,
        master.annotations.description,
        master.annotations.ch_names,
    ):
        annotation_rows.append(
            {
                "onset_sec": float(onset),
                "duration_sec": float(duration),
                "standard_label": str(description),
                "channels": ",".join(channels) if channels else "all",
                "reviewer": reviewer,
                "review_version": stamp,
            }
        )
    _write_tsv(
        output / f"{base}_annotations.tsv",
        annotation_rows,
        [
            "onset_sec",
            "duration_sec",
            "standard_label",
            "channels",
            "reviewer",
            "review_version",
        ],
    )
    _write_tsv(
        output / f"{base}_label_audit.tsv",
        review["label_audit"],
        [
            "onset_sec",
            "duration_sec",
            "raw_label",
            "standard_label",
            "reviewer_note",
        ],
    )
    _write_tsv(
        output / f"{base}_channels.tsv",
        review["channel_audit"],
        [
            "original_channel",
            "standard_channel",
            "globally_bad",
            "reason",
        ],
    )

    summary = {
        "participant_id": participant,
        "run_id": run,
        "reviewer": reviewer,
        "file_context": values["context"],
        "review_created_utc": stamp,
        "source_extension": review["source"].suffix.lower(),
        "source_sha256": _sha256(review["source"]),
        "source_filename_omitted_to_reduce_phi_risk": True,
        "source_sampling_frequency_hz": float(master.info["sfreq"]),
        "sampling_frequency_hz": float(processed.info["sfreq"]),
        "n_channels": len(master.ch_names),
        "globally_bad_channels": list(master.info["bads"]),
        "n_annotations": len(master.annotations),
        "saved_signal": {
            "bandpass_hz": [0.5, 50.0],
            "resampled_to_hz": float(processed.info["sfreq"]),
            "reference": "common average across all EEG channels",
            "saved_as_authoritative_signal": True,
            "normalization": "one global z-score across all EEG channels and samples after common average reference",
            "data_unit": "global z-score (dimensionless)",
            "power_spectral_density_unit": "global z-score squared per Hz",
        },
        "ica_applied": False,
        "physical_unit_eeg_saved": False,
        "average_referenced": True,
        "global_zscore_saved": True,
    }
    with (output / f"{base}_review.json").open("w", encoding="utf-8") as handle:
        json.dump(summary, handle, indent=2)

    QMessageBox.information(
        None,
        "Review saved",
        "The reviewed 250 Hz, 0.5–50 Hz filtered, average-referenced global z-score EEG "
        "and audit tables were saved to:\n\n"
        f"{output}\n\n"
        "Reopen the reviewed FIF for verification before sharing.",
    )
    return output


def make_plotly_display_eeg(review, eeg):
    """Return the legacy EEG dictionary using the filtered physical signal."""
    eeg = sync_legacy_eeg_dictionary(review, eeg)
    display_eeg = dict(eeg)
    display_eeg["data"] = review["filtered"].get_data()
    display_eeg["labels"] = list(review["filtered"].ch_names)
    display_eeg["srate"] = float(review["filtered"].info["sfreq"])
    display_eeg["n_samples"] = int(review["filtered"].n_times)
    display_eeg["duration_sec"] = (
        float(review["filtered"].times[-1])
        if review["filtered"].n_times
        else 0.0
    )
    display_eeg["markers"] = list(eeg["markers"])
    return display_eeg

# %% [markdown]
# ## 3. choose and load one queued recording.

# %%
# Step 3: choose and load one queued recording.
# A Windows dialog asks which selected file to review.
# This creates:
#   review['master']   = original physical-unit EEG with editable metadata
#   review['filtered'] = separate 250 Hz, 0.5–50 Hz average-referenced global z-score copy
#   review['display']  = GUI-scaled copy of the global z-score data

review = prepare_gui_recording(VHDR_FILES)
VHDR_FILE = str(review["source"])

# Keep the original notebook dictionary for the later spectrogram/export cells.
eeg = load_brainvision(VHDR_FILE)

print("Loaded:", Path(VHDR_FILE).name)
print("Channels:", len(review["master"].ch_names), review["master"].ch_names)
print("Source sampling rate:", review["master"].info["sfreq"], "Hz")
print("Processed sampling rate:", review["filtered"].info["sfreq"], "Hz")
print("Duration:", round(review["master"].times[-1], 3), "seconds")
print("Existing annotations:", len(review["master"].annotations))
print("Ready for Step 4.")
# Out:
# Loaded: 20260612_test.vhdr
# Channels: 8 ['F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2']
# Source sampling rate: 1000.0 Hz
# Processed sampling rate: 250.0 Hz
# Duration: 1779.459 seconds
# Existing annotations: 729
# Ready for Step 4.

# %% [markdown]
# ## Markers sorting (Optional)

# %%
# Insert immediately before Step 4.
# Marker audit + standardized replacement + optional Step 4 subsection selection.

import re
import numpy as np
import mne
from PyQt6.QtCore import Qt
from PyQt6.QtWidgets import (
    QAbstractItemView,
    QComboBox,
    QDialog,
    QGroupBox,
    QHBoxLayout,
    QLabel,
    QMessageBox,
    QPushButton,
    QTableWidget,
    QTableWidgetItem,
    QVBoxLayout,
    QDoubleSpinBox,
    QHeaderView,
)

# -------------------------------------------------------------------
# Utilities
# -------------------------------------------------------------------

def _rows_from_annotations(raw):
    """Return rows in a table-friendly structure."""
    if len(raw.annotations) == 0:
        return []

    rows = []
    for i, (onset, duration, label) in enumerate(
        zip(raw.annotations.onset, raw.annotations.duration, raw.annotations.description)
    ):
        rows.append(
            {
                "index": i,
                "label": str(label),
                "onset": float(onset),
                "duration": float(duration),
                "channels": list(raw.annotations.ch_names[i]) if len(raw.annotations.ch_names) > i else [],
            }
        )
    return rows


def _copy_annotations(annotations):
    return mne.Annotations(
        onset=np.asarray(annotations.onset, dtype=float).copy(),
        duration=np.asarray(annotations.duration, dtype=float).copy(),
        description=np.asarray(annotations.description, dtype=object).copy(),
        orig_time=annotations.orig_time,
        ch_names=list(annotations.ch_names),
    )


def _norm_label(value):
    return re.sub(r"\s+", "", str(value)).casefold()


# -------------------------------------------------------------------
# Main dialogue
# -------------------------------------------------------------------

class MarkerSortDialog(QDialog):
    def __init__(self, review):
        super().__init__()
        self.review = review
        self.raw = review["master"]
        self.all_rows = _rows_from_annotations(self.raw)
        self.visible_rows = self.all_rows[:]

        self.setWindowTitle("Marker sorting and Step 4 section selection")
        self.resize(1200, 700)

        layout = QVBoxLayout(self)

        # ---------- time window ----------
        window_box = QGroupBox("Filter markers by time window")
        window_layout = QHBoxLayout(window_box)

        window_layout.addWidget(QLabel("Start (s):"))
        self.start_box = QDoubleSpinBox()
        self.start_box.setRange(-3600, 3600)
        self.start_box.setValue(0.0)
        self.start_box.setDecimals(3)
        self.start_box.setSingleStep(0.1)
        window_layout.addWidget(self.start_box)

        window_layout.addWidget(QLabel("End (s):"))
        self.end_box = QDoubleSpinBox()
        self.end_box.setRange(-3600, 3600)
        max_time = float(self.raw.times[-1]) if len(self.raw.times) else 300.0
        self.end_box.setValue(max_time)
        self.end_box.setDecimals(3)
        self.end_box.setSingleStep(0.1)
        window_layout.addWidget(self.end_box)

        window_layout.addWidget(QLabel("Shift all markers (s):"))
        self.shift_box = QDoubleSpinBox()
        self.shift_box.setRange(-3600, 3600)
        self.shift_box.setValue(0.0)
        self.shift_box.setDecimals(3)
        self.shift_box.setSingleStep(0.1)
        window_layout.addWidget(self.shift_box)

        layout.addWidget(window_box)

        # ---------- batch actions ----------
        batch_box = QGroupBox("Batch actions")
        batch_layout = QHBoxLayout(batch_box)

        refresh_btn = QPushButton("Refresh window")
        refresh_btn.clicked.connect(self.refresh_table)
        batch_layout.addWidget(refresh_btn)

        select_visible_btn = QPushButton("Select all visible")
        select_visible_btn.clicked.connect(self.select_visible_rows)
        batch_layout.addWidget(select_visible_btn)

        select_matching_btn = QPushButton("Select all matching label")
        select_matching_btn.clicked.connect(self.select_matching_label)
        batch_layout.addWidget(select_matching_btn)

        shift_btn = QPushButton("Apply shift")
        shift_btn.clicked.connect(self.apply_shift_to_all)
        batch_layout.addWidget(shift_btn)

        delete_btn = QPushButton("Delete selected rows")
        delete_btn.clicked.connect(self.delete_selected_rows)
        batch_layout.addWidget(delete_btn)

        clear_btn = QPushButton("Clear selection")
        clear_btn.clicked.connect(self.clear_selection)
        batch_layout.addWidget(clear_btn)

        layout.addWidget(batch_box)

        # ---------- replace existing standardized labels ----------
        replace_box = QGroupBox("Replace selected rows with standard label")
        replace_layout = QHBoxLayout(replace_box)

        replace_layout.addWidget(QLabel("Standardized label:"))
        self.replace_combo = QComboBox()
        self.replace_combo.addItems(STANDARD_LABELS)
        replace_layout.addWidget(self.replace_combo)

        replace_selected_btn = QPushButton("Replace selected")
        replace_selected_btn.clicked.connect(self.replace_selected_labels)
        replace_layout.addWidget(replace_selected_btn)

        layout.addWidget(replace_box)

        # ---------- step 4 subsection ----------
        step4_box = QGroupBox("Optional Step 4 subsection")
        step4_layout = QHBoxLayout(step4_box)

        step4_layout.addWidget(QLabel("Start (s):"))
        self.step4_start = QDoubleSpinBox()
        self.step4_start.setRange(-3600, 3600)
        self.step4_start.setValue(0.0)
        self.step4_start.setDecimals(3)
        self.step4_start.setSingleStep(0.1)
        step4_layout.addWidget(self.step4_start)

        step4_layout.addWidget(QLabel("End (s):"))
        self.step4_end = QDoubleSpinBox()
        self.step4_end.setRange(-3600, 3600)
        self.step4_end.setValue(float(self.raw.times[-1]) if len(self.raw.times) else 300.0)
        self.step4_end.setDecimals(3)
        self.step4_end.setSingleStep(0.1)
        step4_layout.addWidget(self.step4_end)

        save_section_btn = QPushButton("Save subsection for Step 4")
        save_section_btn.clicked.connect(self.save_step4_section)
        step4_layout.addWidget(save_section_btn)

        layout.addWidget(step4_box)

        # ---------- table ----------
        self.table = QTableWidget()
        self.table.setColumnCount(5)
        self.table.setHorizontalHeaderLabels(
            ["Index", "Label", "Onset (s)", "Duration (s)", "Channels"]
        )
        self.table.setSelectionBehavior(QAbstractItemView.SelectionBehavior.SelectRows)
        self.table.setSelectionMode(QAbstractItemView.SelectionMode.ExtendedSelection)
        self.table.horizontalHeader().setSectionResizeMode(QHeaderView.ResizeMode.Stretch)
        layout.addWidget(self.table)

        self.refresh_table()

    # ---------- refresh ----------
    def _window_filter(self):
        start = float(self.start_box.value())
        end = float(self.end_box.value())
        if end < start:
            start, end = end, start

        visible = []
        for row in self.all_rows:
            if start <= row["onset"] <= end:
                visible.append(row)
        return visible

    def refresh_table(self):
        self.visible_rows = self._window_filter()
        self.table.setRowCount(len(self.visible_rows))

        for r, row in enumerate(self.visible_rows):
            self.table.setItem(r, 0, QTableWidgetItem(str(row["index"])))
            self.table.setItem(r, 1, QTableWidgetItem(row["label"]))
            self.table.setItem(r, 2, QTableWidgetItem(f"{row['onset']:.3f}"))
            self.table.setItem(r, 3, QTableWidgetItem(f"{row['duration']:.3f}"))
            ch_text = ",".join(row["channels"]) if row["channels"] else "all"
            self.table.setItem(r, 4, QTableWidgetItem(ch_text))

        self.table.clearSelection()

    # ---------- selection ----------
    def select_visible_rows(self):
        for r in range(self.table.rowCount()):
            self.table.selectRow(r)

    def select_matching_label(self):
        selected = self.table.selectionModel().selectedRows() if self.table.selectionModel() else []
        if not selected:
            QMessageBox.warning(self, "No row selected", "Select one annotation row first.")
            return

        active_row = selected[0].row()
        target_label = self.table.item(active_row, 1).text() if self.table.item(active_row, 1) else ""

        match_rows = []
        for r in range(self.table.rowCount()):
            item = self.table.item(r, 1)
            if item and _norm_label(item.text()) == _norm_label(target_label):
                match_rows.append(r)

        self.table.clearSelection()
        for r in match_rows:
            self.table.selectRow(r)

    def clear_selection(self):
        self.table.clearSelection()

    # ---------- replace selected labels ----------
    def replace_selected_labels(self):
        selected_rows = self.table.selectionModel().selectedRows() if self.table.selectionModel() else []
        if not selected_rows:
            QMessageBox.warning(self, "No rows selected", "Select one or more annotation rows first.")
            return

        target_label = self.replace_combo.currentText().strip()
        if not target_label:
            QMessageBox.warning(self, "No replacement label", "Choose a standardized label first.")
            return

        all_indices = sorted(
            {
                self.visible_rows[index.row()]["index"]
                for index in selected_rows
                if 0 <= index.row() < len(self.visible_rows)
            }
        )

        anns = self.raw.annotations
        new_onset = list(anns.onset)
        new_duration = list(anns.duration)
        new_desc = list(anns.description)
        new_ch_names = list(anns.ch_names)

        for idx in reversed(all_indices):
            new_desc[idx] = target_label

        self.raw.set_annotations(
            mne.Annotations(
                onset=np.asarray(new_onset, dtype=float),
                duration=np.asarray(new_duration, dtype=float),
                description=np.asarray(new_desc, dtype=object),
                orig_time=anns.orig_time,
                ch_names=list(new_ch_names),
            )
        )

        for target in (self.review["filtered"], self.review["display"]):
            target.set_annotations(_copy_annotations(self.raw.annotations))

        self.all_rows = _rows_from_annotations(self.raw)
        self.refresh_table()

    # ---------- shift all ----------
    def apply_shift_to_all(self):
        shift = float(self.shift_box.value())
        if abs(shift) < 1e-12:
            return

        for target in (self.review["master"], self.review["filtered"], self.review["display"]):
            anns = target.annotations
            if len(anns) == 0:
                continue

            target.set_annotations(
                mne.Annotations(
                    onset=np.asarray(anns.onset, dtype=float) + shift,
                    duration=np.asarray(anns.duration, dtype=float).copy(),
                    description=np.asarray(anns.description, dtype=object).copy(),
                    orig_time=anns.orig_time,
                    ch_names=list(anns.ch_names),
                )
            )

        self.all_rows = _rows_from_annotations(self.review["master"])
        self.refresh_table()

    # ---------- delete ----------
    def delete_selected_rows(self):
        selected_rows = self.table.selectionModel().selectedRows() if self.table.selectionModel() else []
        if not selected_rows:
            QMessageBox.warning(self, "No rows selected", "Select one or more annotation rows first.")
            return

        all_indices = sorted(
            {
                self.visible_rows[index.row()]["index"]
                for index in selected_rows
                if 0 <= index.row() < len(self.visible_rows)
            }
        )

        if not all_indices:
            return

        answer = QMessageBox.question(
            self,
            "Delete selected markers",
            f"Delete {len(all_indices)} selected markers?",
            QMessageBox.StandardButton.Yes | QMessageBox.StandardButton.No,
            QMessageBox.StandardButton.No,
        )
        if answer != QMessageBox.StandardButton.Yes:
            return

        keep_mask = []
        for i in range(len(self.raw.annotations)):
            keep_mask.append(i not in all_indices)

        if not any(keep_mask):
            self.raw.set_annotations(mne.Annotations([], [], [], orig_time=self.raw.annotations.orig_time))
        else:
            keep_idx = np.where(np.array(keep_mask, dtype=bool))[0]
            self.raw.set_annotations(
                mne.Annotations(
                    onset=np.asarray(self.raw.annotations.onset)[keep_idx].copy(),
                    duration=np.asarray(self.raw.annotations.duration)[keep_idx].copy(),
                    description=np.asarray(self.raw.annotations.description, dtype=object)[keep_idx].copy(),
                    orig_time=self.raw.annotations.orig_time,
                    ch_names=[list(self.raw.annotations.ch_names[i]) for i in keep_idx],
                )
            )

        for target in (self.review["filtered"], self.review["display"]):
            target.set_annotations(_copy_annotations(self.raw.annotations))

        self.all_rows = _rows_from_annotations(self.raw)
        self.refresh_table()

    # ---------- save optional Step 4 subsection ----------
    def save_step4_section(self):
        start_sec = float(self.step4_start.value())
        end_sec = float(self.step4_end.value())

        if end_sec < start_sec:
            start_sec, end_sec = end_sec, start_sec

        global STEP4_SUBSECTION_START_SEC, STEP4_SUBSECTION_END_SEC
        STEP4_SUBSECTION_START_SEC = start_sec
        STEP4_SUBSECTION_END_SEC = end_sec

        QMessageBox.information(
            self,
            "Step 4 subsection saved",
            f"Step 4 will load only the time range {start_sec:.3f}s to {end_sec:.3f}s.\n\n"
            "You can rerun Step 4 for a different subsection later.",
        )

# -------------------------------------------------------------------
# Run the dialog
# -------------------------------------------------------------------

marker_sort_dialog = MarkerSortDialog(review)
marker_sort_dialog.exec()

print("Remaining markers after sorting:")
for i, (onset, duration, label) in enumerate(
    zip(review["master"].annotations.onset, review["master"].annotations.duration, review["master"].annotations.description)
):
    print(f"{i}: {label} | onset={float(onset):.3f}s | duration={float(duration):.3f}s")

# Optional globals saved for Step 4:
if "STEP4_SUBSECTION_START_SEC" in globals():
    print("Step 4 subsection start:", STEP4_SUBSECTION_START_SEC)
    print("Step 4 subsection end:", STEP4_SUBSECTION_END_SEC)
# Out:
# Remaining markers after sorting:
# 0: SSAEP40_stop | onset=206.197s | duration=0.001s
# 1: Oddball_start | onset=952.780s | duration=0.001s
# 2: Primary/P  1 | onset=953.141s | duration=0.001s
# 3: Primary/P  1 | onset=953.227s | duration=0.001s
# 4: Primary/P  1 | onset=953.382s | duration=0.001s
# 5: Primary/P  1 | onset=955.158s | duration=0.001s
# 6: Primary/P  1 | onset=956.542s | duration=0.001s
# 7: Primary/P  1 | onset=957.168s | duration=0.001s
# 8: Primary/P  1 | onset=957.705s | duration=0.001s
# 9: Primary/P  1 | onset=958.439s | duration=0.001s
# 10: Primary/P  1 | onset=958.734s | duration=0.001s
# 11: Primary/P  1 | onset=960.718s | duration=0.001s
# 12: Primary/P  1 | onset=961.215s | duration=0.001s
# 13: Primary/P  1 | onset=961.794s | duration=0.001s
# 14: Primary/P  1 | onset=962.201s | duration=0.001s
# 15: Primary/P  1 | onset=962.275s | duration=0.001s
# 16: Primary/P  1 | onset=962.652s | duration=0.001s
# 17: Primary/P  1 | onset=962.702s | duration=0.001s
# 18: Primary/P  1 | onset=963.668s | duration=0.001s
# 19: Primary/P  1 | onset=963.829s | duration=0.001s
# 20: Primary/P  1 | onset=966.321s | duration=0.001s
# 21: Primary/P  1 | onset=966.351s | duration=0.001s
# 22: Primary/P  1 | onset=966.390s | duration=0.001s
# 23: Primary/P  1 | onset=967.651s | duration=0.001s
# 24: Primary/P  1 | onset=967.729s | duration=0.001s
# 25: Primary/P  1 | onset=967.818s | duration=0.001s
# 26: Primary/P  1 | onset=968.193s | duration=0.001s
# 27: Primary/P  1 | onset=969.251s | duration=0.001s
# 28: Primary/P  1 | onset=974.085s | duration=0.001s
# 29: Primary/P  1 | onset=974.374s | duration=0.001s
# 30: Primary/P  1 | onset=974.878s | duration=0.001s
# 31: Primary/P  1 | onset=975.078s | duration=0.001s
# 32: Primary/P  1 | onset=976.875s | duration=0.001s
# 33: Primary/P  1 | onset=977.348s | duration=0.001s
# 34: Primary/P  1 | onset=977.942s | duration=0.001s
# 35: Primary/P  1 | onset=978.297s | duration=0.001s
# 36: Primary/P  1 | onset=978.471s | duration=0.001s
# 37: Primary/P  1 | onset=979.604s | duration=0.001s
# 38: Primary/P  1 | onset=979.698s | duration=0.001s
# 39: Primary/P  1 | onset=979.941s | duration=0.001s
# 40: Primary/P  1 | onset=979.982s | duration=0.001s
# 41: Primary/P  1 | onset=981.248s | duration=0.001s
# 42: Primary/P  1 | onset=982.724s | duration=0.001s
# 43: Primary/P  1 | onset=982.777s | duration=0.001s
# 44: Primary/P  1 | onset=983.046s | duration=0.001s
# 45: Primary/P  1 | onset=983.281s | duration=0.001s
# 46: Primary/P  1 | onset=983.446s | duration=0.001s
# 47: Primary/P  1 | onset=983.646s | duration=0.001s
# 48: Primary/P  1 | onset=984.329s | duration=0.001s
# 49: Primary/P  1 | onset=984.777s | duration=0.001s
# 50: Primary/P  1 | onset=984.924s | duration=0.001s
# 51: Primary/P  1 | onset=985.714s | duration=0.001s
# 52: Primary/P  1 | onset=985.777s | duration=0.001s
# 53: Primary/P  1 | onset=986.951s | duration=0.001s
# 54: Primary/P  1 | onset=987.277s | duration=0.001s
# 55: Primary/P  1 | onset=987.402s | duration=0.001s
# 56: Primary/P  1 | onset=988.542s | duration=0.001s
# 57: Primary/P  1 | onset=990.945s | duration=0.001s
# 58: Primary/P  1 | onset=991.756s | duration=0.001s
# 59: Primary/P  1 | onset=991.777s | duration=0.001s
# 60: Primary/P  1 | onset=992.931s | duration=0.001s
# 61: Primary/P  1 | onset=993.031s | duration=0.001s
# 62: Primary/P  1 | onset=993.272s | duration=0.001s
# 63: Primary/P  1 | onset=994.475s | duration=0.001s
# 64: Primary/P  1 | onset=996.536s | duration=0.001s
# 65: Primary/P  1 | onset=997.480s | duration=0.001s
# 66: Primary/P  1 | onset=998.213s | duration=0.001s
# 67: Primary/P  1 | onset=998.277s | duration=0.001s
# 68: Primary/P  1 | onset=999.046s | duration=0.001s
# 69: Primary/P  1 | onset=1004.350s | duration=0.001s
# 70: Primary/P  1 | onset=1004.777s | duration=0.001s
# 71: Primary/P  1 | onset=1005.375s | duration=0.001s
# 72: Primary/P  1 | onset=1006.755s | duration=0.001s
# 73: Primary/P  1 | onset=1008.277s | duration=0.001s
# 74: Primary/P  1 | onset=1009.733s | duration=0.001s
# 75: Primary/P  1 | onset=1011.858s | duration=0.001s
# 76: Primary/P  1 | onset=1013.126s | duration=0.001s
# 77: Primary/P  1 | onset=1013.277s | duration=0.001s
# 78: Primary/P  1 | onset=1013.777s | duration=0.001s
# 79: Primary/P  1 | onset=1014.277s | duration=0.001s
# 80: Primary/P  1 | onset=1015.777s | duration=0.001s
# 81: Primary/P  1 | onset=1016.277s | duration=0.001s
# 82: Primary/P  1 | onset=1017.655s | duration=0.001s
# 83: Primary/P  1 | onset=1017.937s | duration=0.001s
# 84: Primary/P  1 | onset=1018.443s | duration=0.001s
# 85: Primary/P  1 | onset=1018.529s | duration=0.001s
# 86: Primary/P  1 | onset=1019.726s | duration=0.001s
# 87: Primary/P  1 | onset=1020.777s | duration=0.001s
# 88: Primary/P  1 | onset=1025.277s | duration=0.001s
# 89: Primary/P  1 | onset=1026.277s | duration=0.001s
# 90: Primary/P  1 | onset=1028.277s | duration=0.001s
# 91: Primary/P  1 | onset=1031.277s | duration=0.001s
# 92: Primary/P  1 | onset=1032.277s | duration=0.001s
# 93: Primary/P  1 | onset=1033.008s | duration=0.001s
# 94: Primary/P  1 | onset=1033.497s | duration=0.001s
# 95: Primary/P  1 | onset=1033.777s | duration=0.001s
# 96: Primary/P  1 | onset=1038.777s | duration=0.001s
# 97: Primary/P  1 | onset=1041.277s | duration=0.001s
# 98: Primary/P  1 | onset=1042.277s | duration=0.001s
# 99: Primary/P  1 | onset=1043.277s | duration=0.001s
# 100: Primary/P  1 | onset=1043.937s | duration=0.001s
# 101: Primary/P  1 | onset=1044.777s | duration=0.001s
# 102: Primary/P  1 | onset=1046.777s | duration=0.001s
# 103: Primary/P  1 | onset=1051.277s | duration=0.001s
# 104: Primary/P  1 | onset=1051.777s | duration=0.001s
# 105: Primary/P  1 | onset=1055.777s | duration=0.001s
# 106: Primary/P  1 | onset=1056.063s | duration=0.001s
# 107: Primary/P  1 | onset=1056.777s | duration=0.001s
# 108: Primary/P  1 | onset=1059.277s | duration=0.001s
# 109: Primary/P  1 | onset=1061.777s | duration=0.001s
# 110: Primary/P  1 | onset=1061.860s | duration=0.001s
# 111: Primary/P  1 | onset=1065.715s | duration=0.001s
# 112: Primary/P  1 | onset=1150.277s | duration=0.001s
# 113: Primary/P  1 | onset=1151.777s | duration=0.001s
# 114: Primary/P  1 | onset=1159.777s | duration=0.001s
# 115: Primary/P  1 | onset=1161.277s | duration=0.001s
# 116: Primary/P  1 | onset=1162.777s | duration=0.001s
# 117: Primary/P  1 | onset=1163.777s | duration=0.001s
# 118: Primary/P  1 | onset=1167.777s | duration=0.001s
# 119: Primary/P  1 | onset=1185.277s | duration=0.001s
# 120: Primary/P  1 | onset=1187.777s | duration=0.001s
# 121: Primary/P  1 | onset=1207.277s | duration=0.001s
# 122: Primary/P  1 | onset=1214.277s | duration=0.001s
# 123: Primary/P  1 | onset=1215.777s | duration=0.001s
# 124: Primary/P  1 | onset=1216.172s | duration=0.001s
# 125: Primary/P  1 | onset=1217.277s | duration=0.001s
# 126: Primary/P  1 | onset=1224.186s | duration=0.001s
# 127: Primary/P  1 | onset=1227.277s | duration=0.001s
# 128: Primary/P  1 | onset=1228.277s | duration=0.001s
# 129: Primary/P  1 | onset=1228.813s | duration=0.001s
# 130: Primary/P  1 | onset=1229.277s | duration=0.001s
# 131: Primary/P  1 | onset=1230.277s | duration=0.001s
# 132: Primary/P  1 | onset=1238.277s | duration=0.001s
# 133: Primary/P  1 | onset=1239.277s | duration=0.001s
# 134: Primary/P  1 | onset=1240.777s | duration=0.001s
# 135: Primary/P  1 | onset=1241.076s | duration=0.001s
# 136: Primary/P  1 | onset=1246.577s | duration=0.001s
# 137: Primary/P  1 | onset=1248.777s | duration=0.001s
# 138: Primary/P  1 | onset=1251.033s | duration=0.001s
# 139: Primary/P  1 | onset=1253.277s | duration=0.001s
# 140: Primary/P  1 | onset=1253.777s | duration=0.001s
# 141: Primary/P  1 | onset=1258.520s | duration=0.001s
# 142: Primary/P  1 | onset=1259.171s | duration=0.001s
# 143: Primary/P  1 | onset=1260.777s | duration=0.001s
# 144: Primary/P  1 | onset=1260.795s | duration=0.001s
# 145: Primary/P  1 | onset=1261.976s | duration=0.001s
# 146: Primary/P  1 | onset=1262.777s | duration=0.001s
# 147: Primary/P  1 | onset=1263.372s | duration=0.001s
# 148: Primary/P  1 | onset=1263.902s | duration=0.001s
# 149: Primary/P  1 | onset=1264.000s | duration=0.001s
# 150: Primary/P  1 | onset=1267.277s | duration=0.001s
# 151: Primary/P  1 | onset=1269.865s | duration=0.001s
# 152: Primary/P  1 | onset=1270.895s | duration=0.001s
# 153: Primary/P  1 | onset=1271.145s | duration=0.001s
# 154: Primary/P  1 | onset=1272.277s | duration=0.001s
# 155: Primary/P  1 | onset=1273.777s | duration=0.001s
# 156: Primary/P  1 | onset=1275.545s | duration=0.001s
# 157: Primary/P  1 | onset=1276.693s | duration=0.001s
# 158: Primary/P  1 | onset=1277.546s | duration=0.001s
# 159: Primary/P  1 | onset=1278.182s | duration=0.001s
# 160: Primary/P  1 | onset=1279.445s | duration=0.001s
# 161: Primary/P  1 | onset=1280.278s | duration=0.001s
# 162: Primary/P  1 | onset=1282.198s | duration=0.001s
# 163: Primary/P  1 | onset=1283.277s | duration=0.001s
# 164: Primary/P  1 | onset=1285.453s | duration=0.001s
# 165: Primary/P  1 | onset=1288.596s | duration=0.001s
# 166: Primary/P  1 | onset=1288.849s | duration=0.001s
# 167: Primary/P  1 | onset=1289.015s | duration=0.001s
# 168: Primary/P  1 | onset=1289.230s | duration=0.001s
# 169: Primary/P  1 | onset=1290.599s | duration=0.001s
# 170: Primary/P  1 | onset=1290.996s | duration=0.001s
# 171: Primary/P  1 | onset=1291.893s | duration=0.001s
# 172: Primary/P  1 | onset=1292.242s | duration=0.001s
# 173: Primary/P  1 | onset=1292.903s | duration=0.001s
# 174: Primary/P  1 | onset=1292.925s | duration=0.001s
# 175: Primary/P  1 | onset=1293.145s | duration=0.001s
# 176: Primary/P  1 | onset=1294.464s | duration=0.001s
# 177: Primary/P  1 | onset=1294.741s | duration=0.001s
# 178: Primary/P  1 | onset=1294.810s | duration=0.001s
# 179: Primary/P  1 | onset=1295.016s | duration=0.001s
# 180: Primary/P  1 | onset=1295.162s | duration=0.001s
# 181: Primary/P  1 | onset=1295.966s | duration=0.001s
# 182: Primary/P  1 | onset=1300.898s | duration=0.001s
# 183: Primary/P  1 | onset=1301.777s | duration=0.001s
# 184: Primary/P  1 | onset=1304.829s | duration=0.001s
# 185: Primary/P  1 | onset=1304.961s | duration=0.001s
# 186: Primary/P  1 | onset=1305.539s | duration=0.001s
# 187: Primary/P  1 | onset=1305.564s | duration=0.001s
# 188: Primary/P  1 | onset=1307.123s | duration=0.001s
# 189: Primary/P  1 | onset=1307.618s | duration=0.001s
# 190: Primary/P  1 | onset=1307.689s | duration=0.001s
# 191: Primary/P  1 | onset=1308.068s | duration=0.001s
# 192: Primary/P  1 | onset=1308.370s | duration=0.001s
# 193: Primary/P  1 | onset=1308.521s | duration=0.001s
# 194: Primary/P  1 | onset=1308.682s | duration=0.001s
# 195: Primary/P  1 | onset=1308.784s | duration=0.001s
# 196: Primary/P  1 | onset=1309.100s | duration=0.001s
# 197: Primary/P  1 | onset=1309.281s | duration=0.001s
# 198: Primary/P  1 | onset=1309.355s | duration=0.001s
# 199: Primary/P  1 | onset=1309.420s | duration=0.001s
# 200: Primary/P  1 | onset=1309.670s | duration=0.001s
# 201: Primary/P  1 | onset=1310.320s | duration=0.001s
# 202: Primary/P  1 | onset=1310.764s | duration=0.001s
# 203: Primary/P  1 | onset=1311.385s | duration=0.001s
# 204: Primary/P  1 | onset=1312.062s | duration=0.001s
# 205: Primary/P  1 | onset=1312.152s | duration=0.001s
# 206: Primary/P  1 | onset=1312.832s | duration=0.001s
# 207: Primary/P  1 | onset=1313.106s | duration=0.001s
# 208: Primary/P  1 | onset=1314.401s | duration=0.001s
# 209: Primary/P  1 | onset=1314.570s | duration=0.001s
# 210: Primary/P  1 | onset=1314.673s | duration=0.001s
# 211: Primary/P  1 | onset=1315.152s | duration=0.001s
# 212: Primary/P  1 | onset=1315.654s | duration=0.001s
# 213: Primary/P  1 | onset=1315.782s | duration=0.001s
# 214: Primary/P  1 | onset=1315.853s | duration=0.001s
# 215: Primary/P  1 | onset=1316.193s | duration=0.001s
# 216: Primary/P  1 | onset=1316.834s | duration=0.001s
# 217: Primary/P  1 | onset=1317.083s | duration=0.001s
# 218: Primary/P  1 | onset=1317.137s | duration=0.001s
# 219: Primary/P  1 | onset=1317.638s | duration=0.001s
# 220: Primary/P  1 | onset=1317.804s | duration=0.001s
# 221: Primary/P  1 | onset=1318.002s | duration=0.001s
# 222: Primary/P  1 | onset=1318.569s | duration=0.001s
# 223: Primary/P  1 | onset=1318.833s | duration=0.001s
# 224: Primary/P  1 | onset=1320.052s | duration=0.001s
# 225: Primary/P  1 | onset=1321.353s | duration=0.001s
# 226: Primary/P  1 | onset=1321.443s | duration=0.001s
# 227: Primary/P  1 | onset=1321.665s | duration=0.001s
# 228: Primary/P  1 | onset=1321.804s | duration=0.001s
# 229: Primary/P  1 | onset=1321.866s | duration=0.001s
# 230: Primary/P  1 | onset=1323.159s | duration=0.001s
# 231: Primary/P  1 | onset=1323.453s | duration=0.001s
# 232: Primary/P  1 | onset=1323.514s | duration=0.001s
# 233: Primary/P  1 | onset=1323.680s | duration=0.001s
# 234: Primary/P  1 | onset=1323.751s | duration=0.001s
# 235: Primary/P  1 | onset=1324.192s | duration=0.001s
# 236: Primary/P  1 | onset=1324.370s | duration=0.001s
# 237: Primary/P  1 | onset=1324.449s | duration=0.001s
# 238: Primary/P  1 | onset=1324.553s | duration=0.001s
# 239: Primary/P  1 | onset=1324.569s | duration=0.001s
# 240: Primary/P  1 | onset=1324.939s | duration=0.001s
# 241: Primary/P  1 | onset=1325.071s | duration=0.001s
# 242: Primary/P  1 | onset=1325.101s | duration=0.001s
# 243: Primary/P  1 | onset=1325.674s | duration=0.001s
# 244: Primary/P  1 | onset=1325.833s | duration=0.001s
# 245: Primary/P  1 | onset=1325.940s | duration=0.001s
# 246: Primary/P  1 | onset=1326.570s | duration=0.001s
# 247: Primary/P  1 | onset=1328.054s | duration=0.001s
# 248: Primary/P  1 | onset=1328.074s | duration=0.001s
# 249: Primary/P  1 | onset=1328.202s | duration=0.001s
# 250: Primary/P  1 | onset=1328.340s | duration=0.001s
# 251: Primary/P  1 | onset=1328.459s | duration=0.001s
# 252: Primary/P  1 | onset=1328.633s | duration=0.001s
# 253: Primary/P  1 | onset=1329.314s | duration=0.001s
# 254: Primary/P  1 | onset=1329.649s | duration=0.001s
# 255: Primary/P  1 | onset=1329.702s | duration=0.001s
# 256: Primary/P  1 | onset=1330.421s | duration=0.001s
# 257: Primary/P  1 | onset=1330.431s | duration=0.001s
# 258: Primary/P  1 | onset=1331.463s | duration=0.001s
# 259: Primary/P  1 | onset=1331.661s | duration=0.001s
# 260: Primary/P  1 | onset=1331.784s | duration=0.001s
# 261: Primary/P  1 | onset=1332.041s | duration=0.001s
# 262: Primary/P  1 | onset=1332.085s | duration=0.001s
# 263: Primary/P  1 | onset=1332.584s | duration=0.001s
# 264: Primary/P  1 | onset=1332.778s | duration=0.001s
# 265: Primary/P  1 | onset=1333.122s | duration=0.001s
# 266: Primary/P  1 | onset=1333.372s | duration=0.001s
# 267: Primary/P  1 | onset=1334.905s | duration=0.001s
# 268: Primary/P  1 | onset=1335.035s | duration=0.001s
# 269: Primary/P  1 | onset=1335.124s | duration=0.001s
# 270: Primary/P  1 | onset=1335.348s | duration=0.001s
# 271: Primary/P  1 | onset=1336.085s | duration=0.001s
# 272: Primary/P  1 | onset=1336.136s | duration=0.001s
# 273: Primary/P  1 | onset=1336.295s | duration=0.001s
# 274: Primary/P  1 | onset=1336.470s | duration=0.001s
# 275: Primary/P  1 | onset=1336.774s | duration=0.001s
# 276: Primary/P  1 | onset=1336.950s | duration=0.001s
# 277: Primary/P  1 | onset=1337.592s | duration=0.001s
# 278: Primary/P  1 | onset=1337.876s | duration=0.001s
# 279: Primary/P  1 | onset=1337.973s | duration=0.001s
# 280: Primary/P  1 | onset=1337.982s | duration=0.001s
# 281: Primary/P  1 | onset=1338.275s | duration=0.001s
# 282: Primary/P  1 | onset=1338.438s | duration=0.001s
# 283: Primary/P  1 | onset=1338.570s | duration=0.001s
# 284: Primary/P  1 | onset=1339.169s | duration=0.001s
# 285: Primary/P  1 | onset=1339.650s | duration=0.001s
# 286: Primary/P  1 | onset=1339.853s | duration=0.001s
# 287: Primary/P  1 | onset=1340.286s | duration=0.001s
# 288: Primary/P  1 | onset=1341.386s | duration=0.001s
# 289: Primary/P  1 | onset=1341.392s | duration=0.001s
# 290: Primary/P  1 | onset=1341.452s | duration=0.001s
# 291: Primary/P  1 | onset=1341.540s | duration=0.001s
# 292: Primary/P  1 | onset=1342.335s | duration=0.001s
# 293: Primary/P  1 | onset=1342.369s | duration=0.001s
# 294: Primary/P  1 | onset=1342.522s | duration=0.001s
# 295: Primary/P  1 | onset=1342.721s | duration=0.001s
# 296: Primary/P  1 | onset=1342.756s | duration=0.001s
# 297: Primary/P  1 | onset=1343.496s | duration=0.001s
# 298: Primary/P  1 | onset=1343.636s | duration=0.001s
# 299: Primary/P  1 | onset=1343.851s | duration=0.001s
# 300: Primary/P  1 | onset=1343.861s | duration=0.001s
# 301: Primary/P  1 | onset=1343.935s | duration=0.001s
# 302: Primary/P  1 | onset=1344.006s | duration=0.001s
# 303: Primary/P  1 | onset=1344.754s | duration=0.001s
# 304: Primary/P  1 | onset=1345.372s | duration=0.001s
# 305: Primary/P  1 | onset=1345.594s | duration=0.001s
# 306: Primary/P  1 | onset=1346.035s | duration=0.001s
# 307: Primary/P  1 | onset=1346.392s | duration=0.001s
# 308: Primary/P  1 | onset=1346.808s | duration=0.001s
# 309: Primary/P  1 | onset=1347.019s | duration=0.001s
# 310: Primary/P  1 | onset=1347.695s | duration=0.001s
# 311: Primary/P  1 | onset=1348.441s | duration=0.001s
# 312: Primary/P  1 | onset=1348.774s | duration=0.001s
# 313: Primary/P  1 | onset=1348.991s | duration=0.001s
# 314: Primary/P  1 | onset=1349.170s | duration=0.001s
# 315: Primary/P  1 | onset=1349.212s | duration=0.001s
# 316: Primary/P  1 | onset=1350.255s | duration=0.001s
# 317: Primary/P  1 | onset=1350.486s | duration=0.001s
# 318: Primary/P  1 | onset=1350.586s | duration=0.001s
# 319: Primary/P  1 | onset=1350.739s | duration=0.001s
# 320: Primary/P  1 | onset=1351.124s | duration=0.001s
# 321: Primary/P  1 | onset=1352.204s | duration=0.001s
# 322: Primary/P  1 | onset=1352.966s | duration=0.001s
# 323: Primary/P  1 | onset=1353.821s | duration=0.001s
# 324: Primary/P  1 | onset=1353.868s | duration=0.001s
# 325: Primary/P  1 | onset=1353.910s | duration=0.001s
# 326: Primary/P  1 | onset=1354.048s | duration=0.001s
# 327: Primary/P  1 | onset=1354.158s | duration=0.001s
# 328: Primary/P  1 | onset=1354.425s | duration=0.001s
# 329: Primary/P  1 | onset=1354.828s | duration=0.001s
# 330: Primary/P  1 | onset=1354.864s | duration=0.001s
# 331: Primary/P  1 | onset=1355.611s | duration=0.001s
# 332: Primary/P  1 | onset=1355.711s | duration=0.001s
# 333: Primary/P  1 | onset=1356.005s | duration=0.001s
# 334: Primary/P  1 | onset=1356.340s | duration=0.001s
# 335: Primary/P  1 | onset=1356.549s | duration=0.001s
# 336: Primary/P  1 | onset=1356.771s | duration=0.001s
# 337: Primary/P  1 | onset=1357.361s | duration=0.001s
# 338: Primary/P  1 | onset=1357.739s | duration=0.001s
# 339: Primary/P  1 | onset=1357.810s | duration=0.001s
# 340: Primary/P  1 | onset=1358.005s | duration=0.001s
# 341: Primary/P  1 | onset=1358.079s | duration=0.001s
# 342: Primary/P  1 | onset=1358.331s | duration=0.001s
# 343: Primary/P  1 | onset=1358.350s | duration=0.001s
# 344: Primary/P  1 | onset=1358.778s | duration=0.001s
# 345: Primary/P  1 | onset=1359.623s | duration=0.001s
# 346: Primary/P  1 | onset=1359.660s | duration=0.001s
# 347: Primary/P  1 | onset=1359.795s | duration=0.001s
# 348: Primary/P  1 | onset=1360.130s | duration=0.001s
# 349: Primary/P  1 | onset=1360.278s | duration=0.001s
# 350: Primary/P  1 | onset=1360.342s | duration=0.001s
# 351: Primary/P  1 | onset=1360.415s | duration=0.001s
# 352: Primary/P  1 | onset=1360.759s | duration=0.001s
# 353: Primary/P  1 | onset=1361.706s | duration=0.001s
# 354: Primary/P  1 | onset=1362.374s | duration=0.001s
# 355: Primary/P  1 | onset=1362.409s | duration=0.001s
# 356: Primary/P  1 | onset=1362.579s | duration=0.001s
# 357: Primary/P  1 | onset=1362.824s | duration=0.001s
# 358: Primary/P  1 | onset=1363.396s | duration=0.001s
# 359: Primary/P  1 | onset=1363.671s | duration=0.001s
# 360: Primary/P  1 | onset=1364.094s | duration=0.001s
# 361: Primary/P  1 | onset=1365.144s | duration=0.001s
# 362: Primary/P  1 | onset=1365.295s | duration=0.001s
# 363: Primary/P  1 | onset=1365.566s | duration=0.001s
# 364: Primary/P  1 | onset=1365.881s | duration=0.001s
# 365: Primary/P  1 | onset=1366.417s | duration=0.001s
# 366: Primary/P  1 | onset=1366.493s | duration=0.001s
# 367: Primary/P  1 | onset=1366.519s | duration=0.001s
# 368: Primary/P  1 | onset=1366.574s | duration=0.001s
# 369: Primary/P  1 | onset=1366.619s | duration=0.001s
# 370: Primary/P  1 | onset=1366.809s | duration=0.001s
# 371: Primary/P  1 | onset=1366.941s | duration=0.001s
# 372: Primary/P  1 | onset=1367.157s | duration=0.001s
# 373: Primary/P  1 | onset=1367.929s | duration=0.001s
# 374: Primary/P  1 | onset=1368.232s | duration=0.001s
# 375: Primary/P  1 | onset=1368.593s | duration=0.001s
# 376: Primary/P  1 | onset=1368.862s | duration=0.001s
# 377: Primary/P  1 | onset=1369.114s | duration=0.001s
# 378: Primary/P  1 | onset=1369.375s | duration=0.001s
# 379: Primary/P  1 | onset=1370.001s | duration=0.001s
# 380: Primary/P  1 | onset=1370.074s | duration=0.001s
# 381: Primary/P  1 | onset=1370.476s | duration=0.001s
# 382: Primary/P  1 | onset=1370.576s | duration=0.001s
# 383: Primary/P  1 | onset=1370.778s | duration=0.001s
# 384: Primary/P  1 | onset=1372.013s | duration=0.001s
# 385: Primary/P  1 | onset=1372.161s | duration=0.001s
# 386: Primary/P  1 | onset=1372.626s | duration=0.001s
# 387: Primary/P  1 | onset=1372.801s | duration=0.001s
# 388: Primary/P  1 | onset=1372.857s | duration=0.001s
# 389: Primary/P  1 | onset=1372.876s | duration=0.001s
# 390: Primary/P  1 | onset=1373.143s | duration=0.001s
# 391: Primary/P  1 | onset=1373.167s | duration=0.001s
# 392: Primary/P  1 | onset=1373.278s | duration=0.001s
# 393: Primary/P  1 | onset=1375.031s | duration=0.001s
# 394: Primary/P  1 | onset=1375.196s | duration=0.001s
# 395: Primary/P  1 | onset=1375.595s | duration=0.001s
# 396: Primary/P  1 | onset=1375.696s | duration=0.001s
# 397: Primary/P  1 | onset=1375.961s | duration=0.001s
# 398: Primary/P  1 | onset=1376.093s | duration=0.001s
# 399: Primary/P  1 | onset=1376.765s | duration=0.001s
# 400: Primary/P  1 | onset=1376.917s | duration=0.001s
# 401: Primary/P  1 | onset=1377.052s | duration=0.001s
# 402: Primary/P  1 | onset=1378.076s | duration=0.001s
# 403: Primary/P  1 | onset=1378.244s | duration=0.001s
# 404: Primary/P  1 | onset=1378.720s | duration=0.001s
# 405: Primary/P  1 | onset=1381.778s | duration=0.001s
# 406: Primary/P  1 | onset=1382.350s | duration=0.001s
# 407: Primary/P  1 | onset=1383.314s | duration=0.001s
# 408: Primary/P  1 | onset=1383.667s | duration=0.001s
# 409: Primary/P  1 | onset=1383.686s | duration=0.001s
# 410: Primary/P  1 | onset=1384.697s | duration=0.001s
# 411: Primary/P  1 | onset=1385.079s | duration=0.001s
# 412: Primary/P  1 | onset=1385.564s | duration=0.001s
# 413: Primary/P  1 | onset=1385.580s | duration=0.001s
# 414: Primary/P  1 | onset=1386.179s | duration=0.001s
# 415: Primary/P  1 | onset=1386.997s | duration=0.001s
# 416: Primary/P  1 | onset=1387.320s | duration=0.001s
# 417: Primary/P  1 | onset=1387.778s | duration=0.001s
# 418: Primary/P  1 | onset=1388.361s | duration=0.001s
# 419: Primary/P  1 | onset=1389.317s | duration=0.001s
# 420: Primary/P  1 | onset=1389.774s | duration=0.001s
# 421: Primary/P  1 | onset=1389.778s | duration=0.001s
# 422: Primary/P  1 | onset=1390.312s | duration=0.001s
# 423: Primary/P  1 | onset=1390.500s | duration=0.001s
# 424: Primary/P  1 | onset=1390.946s | duration=0.001s
# 425: Primary/P  1 | onset=1391.778s | duration=0.001s
# 426: Primary/P  1 | onset=1392.215s | duration=0.001s
# 427: Primary/P  1 | onset=1392.311s | duration=0.001s
# 428: Primary/P  1 | onset=1392.930s | duration=0.001s
# 429: Primary/P  1 | onset=1393.004s | duration=0.001s
# 430: Primary/P  1 | onset=1393.501s | duration=0.001s
# 431: Primary/P  1 | onset=1393.811s | duration=0.001s
# 432: Primary/P  1 | onset=1394.778s | duration=0.001s
# 433: Primary/P  1 | onset=1395.196s | duration=0.001s
# 434: Primary/P  1 | onset=1395.895s | duration=0.001s
# 435: Primary/P  1 | onset=1396.083s | duration=0.001s
# 436: Primary/P  1 | onset=1396.278s | duration=0.001s
# 437: Primary/P  1 | onset=1396.282s | duration=0.001s
# 438: Primary/P  1 | onset=1396.311s | duration=0.001s
# 439: Primary/P  1 | onset=1397.526s | duration=0.001s
# 440: Primary/P  1 | onset=1397.532s | duration=0.001s
# 441: Primary/P  1 | onset=1398.482s | duration=0.001s
# 442: Primary/P  1 | onset=1398.930s | duration=0.001s
# 443: Primary/P  1 | onset=1399.412s | duration=0.001s
# 444: Primary/P  1 | onset=1400.280s | duration=0.001s
# 445: Primary/P  1 | onset=1401.536s | duration=0.001s
# 446: Primary/P  1 | onset=1402.349s | duration=0.001s
# 447: Primary/P  1 | onset=1404.515s | duration=0.001s
# 448: Primary/P  1 | onset=1404.545s | duration=0.001s
# 449: Primary/P  1 | onset=1404.964s | duration=0.001s
# 450: Primary/P  1 | onset=1405.363s | duration=0.001s
# 451: Primary/P  1 | onset=1405.401s | duration=0.001s
# 452: Primary/P  1 | onset=1405.431s | duration=0.001s
# 453: Primary/P  1 | onset=1405.496s | duration=0.001s
# 454: Primary/P  1 | onset=1405.579s | duration=0.001s
# 455: Primary/P  1 | onset=1406.315s | duration=0.001s
# 456: Primary/P  1 | onset=1407.567s | duration=0.001s
# 457: Primary/P  1 | onset=1407.671s | duration=0.001s
# 458: Primary/P  1 | onset=1407.845s | duration=0.001s
# 459: Primary/P  1 | onset=1408.501s | duration=0.001s
# 460: Primary/P  1 | onset=1408.778s | duration=0.001s
# 461: Primary/P  1 | onset=1409.200s | duration=0.001s
# 462: Primary/P  1 | onset=1409.311s | duration=0.001s
# 463: Primary/P  1 | onset=1409.664s | duration=0.001s
# 464: Primary/P  1 | onset=1409.884s | duration=0.001s
# 465: Primary/P  1 | onset=1410.394s | duration=0.001s
# 466: Primary/P  1 | onset=1410.454s | duration=0.001s
# 467: Primary/P  1 | onset=1410.495s | duration=0.001s
# 468: Primary/P  1 | onset=1410.635s | duration=0.001s
# 469: Primary/P  1 | onset=1410.778s | duration=0.001s
# 470: Primary/P  1 | onset=1410.862s | duration=0.001s
# 471: Primary/P  1 | onset=1410.917s | duration=0.001s
# 472: Primary/P  1 | onset=1411.271s | duration=0.001s
# 473: Primary/P  1 | onset=1411.385s | duration=0.001s
# 474: Primary/P  1 | onset=1411.841s | duration=0.001s
# 475: Primary/P  1 | onset=1412.170s | duration=0.001s
# 476: Primary/P  1 | onset=1412.179s | duration=0.001s
# 477: Primary/P  1 | onset=1413.278s | duration=0.001s
# 478: Primary/P  1 | onset=1413.663s | duration=0.001s
# 479: Primary/P  1 | onset=1413.831s | duration=0.001s
# 480: Primary/P  1 | onset=1414.136s | duration=0.001s
# 481: Primary/P  1 | onset=1414.430s | duration=0.001s
# 482: Primary/P  1 | onset=1414.951s | duration=0.001s
# 483: Primary/P  1 | onset=1415.082s | duration=0.001s
# 484: Primary/P  1 | onset=1415.778s | duration=0.001s
# 485: Primary/P  1 | onset=1415.810s | duration=0.001s
# 486: Primary/P  1 | onset=1416.366s | duration=0.001s
# 487: Primary/P  1 | onset=1416.719s | duration=0.001s
# 488: Primary/P  1 | onset=1417.324s | duration=0.001s
# 489: Primary/P  1 | onset=1417.365s | duration=0.001s
# 490: Primary/P  1 | onset=1417.635s | duration=0.001s
# 491: Primary/P  1 | onset=1417.752s | duration=0.001s
# 492: Primary/P  1 | onset=1417.816s | duration=0.001s
# 493: Primary/P  1 | onset=1417.886s | duration=0.001s
# 494: Primary/P  1 | onset=1418.404s | duration=0.001s
# 495: Primary/P  1 | onset=1418.792s | duration=0.001s
# 496: Primary/P  1 | onset=1418.970s | duration=0.001s
# 497: Primary/P  1 | onset=1419.316s | duration=0.001s
# 498: Primary/P  1 | onset=1419.939s | duration=0.001s
# 499: Primary/P  1 | onset=1420.522s | duration=0.001s
# 500: Primary/P  1 | onset=1420.974s | duration=0.001s
# 501: Primary/P  1 | onset=1421.494s | duration=0.001s
# 502: Primary/P  1 | onset=1421.635s | duration=0.001s
# 503: Primary/P  1 | onset=1422.255s | duration=0.001s
# 504: Primary/P  1 | onset=1422.741s | duration=0.001s
# 505: Primary/P  1 | onset=1422.824s | duration=0.001s
# 506: Primary/P  1 | onset=1423.133s | duration=0.001s
# 507: Primary/P  1 | onset=1423.152s | duration=0.001s
# 508: Primary/P  1 | onset=1423.171s | duration=0.001s
# 509: Primary/P  1 | onset=1423.854s | duration=0.001s
# 510: Primary/P  1 | onset=1424.219s | duration=0.001s
# 511: Primary/P  1 | onset=1424.405s | duration=0.001s
# 512: Primary/P  1 | onset=1424.509s | duration=0.001s
# 513: Primary/P  1 | onset=1424.634s | duration=0.001s
# 514: Primary/P  1 | onset=1424.644s | duration=0.001s
# 515: Primary/P  1 | onset=1424.692s | duration=0.001s
# 516: Primary/P  1 | onset=1424.752s | duration=0.001s
# 517: Primary/P  1 | onset=1424.778s | duration=0.001s
# 518: Primary/P  1 | onset=1425.125s | duration=0.001s
# 519: Primary/P  1 | onset=1425.778s | duration=0.001s
# 520: Primary/P  1 | onset=1426.217s | duration=0.001s
# 521: Primary/P  1 | onset=1426.523s | duration=0.001s
# 522: Primary/P  1 | onset=1426.559s | duration=0.001s
# 523: Primary/P  1 | onset=1426.778s | duration=0.001s
# 524: Primary/P  1 | onset=1426.836s | duration=0.001s
# 525: Primary/P  1 | onset=1427.824s | duration=0.001s
# 526: Primary/P  1 | onset=1427.843s | duration=0.001s
# 527: Primary/P  1 | onset=1428.007s | duration=0.001s
# 528: Primary/P  1 | onset=1428.072s | duration=0.001s
# 529: Primary/P  1 | onset=1428.913s | duration=0.001s
# 530: Primary/P  1 | onset=1429.027s | duration=0.001s
# 531: Primary/P  1 | onset=1430.192s | duration=0.001s
# 532: Primary/P  1 | onset=1430.239s | duration=0.001s
# 533: Primary/P  1 | onset=1430.278s | duration=0.001s
# 534: Primary/P  1 | onset=1430.459s | duration=0.001s
# 535: Primary/P  1 | onset=1430.924s | duration=0.001s
# 536: Primary/P  1 | onset=1430.963s | duration=0.001s
# 537: Primary/P  1 | onset=1431.307s | duration=0.001s
# 538: Primary/P  1 | onset=1432.255s | duration=0.001s
# 539: Primary/P  1 | onset=1432.722s | duration=0.001s
# 540: Primary/P  1 | onset=1432.845s | duration=0.001s
# 541: Primary/P  1 | onset=1432.921s | duration=0.001s
# 542: Primary/P  1 | onset=1433.205s | duration=0.001s
# 543: Primary/P  1 | onset=1433.540s | duration=0.001s
# 544: Primary/P  1 | onset=1433.778s | duration=0.001s
# 545: Primary/P  1 | onset=1433.811s | duration=0.001s
# 546: Primary/P  1 | onset=1433.840s | duration=0.001s
# 547: Primary/P  1 | onset=1434.024s | duration=0.001s
# 548: Primary/P  1 | onset=1434.029s | duration=0.001s
# 549: Primary/P  1 | onset=1434.033s | duration=0.001s
# 550: Primary/P  1 | onset=1435.014s | duration=0.001s
# 551: Primary/P  1 | onset=1435.050s | duration=0.001s
# 552: Primary/P  1 | onset=1435.403s | duration=0.001s
# 553: Primary/P  1 | onset=1436.140s | duration=0.001s
# 554: Primary/P  1 | onset=1436.489s | duration=0.001s
# 555: Primary/P  1 | onset=1436.778s | duration=0.001s
# 556: Primary/P  1 | onset=1439.073s | duration=0.001s
# 557: Primary/P  1 | onset=1440.278s | duration=0.001s
# 558: Primary/P  1 | onset=1440.390s | duration=0.001s
# 559: Primary/P  1 | onset=1440.995s | duration=0.001s
# 560: Primary/P  1 | onset=1441.778s | duration=0.001s
# 561: Primary/P  1 | onset=1442.182s | duration=0.001s
# 562: Primary/P  1 | onset=1442.278s | duration=0.001s
# 563: Primary/P  1 | onset=1442.423s | duration=0.001s
# 564: Primary/P  1 | onset=1443.197s | duration=0.001s
# 565: Primary/P  1 | onset=1443.278s | duration=0.001s
# 566: Primary/P  1 | onset=1443.536s | duration=0.001s
# 567: Primary/P  1 | onset=1444.025s | duration=0.001s
# 568: Primary/P  1 | onset=1444.778s | duration=0.001s
# 569: Primary/P  1 | onset=1444.878s | duration=0.001s
# 570: Primary/P  1 | onset=1444.949s | duration=0.001s
# 571: Primary/P  1 | onset=1446.069s | duration=0.001s
# 572: Primary/P  1 | onset=1446.778s | duration=0.001s
# 573: Primary/P  1 | onset=1447.278s | duration=0.001s
# 574: Primary/P  1 | onset=1447.393s | duration=0.001s
# 575: Primary/P  1 | onset=1447.593s | duration=0.001s
# 576: Primary/P  1 | onset=1448.081s | duration=0.001s
# 577: Primary/P  1 | onset=1448.278s | duration=0.001s
# 578: Primary/P  1 | onset=1448.363s | duration=0.001s
# 579: Primary/P  1 | onset=1448.614s | duration=0.001s
# 580: Primary/P  1 | onset=1450.278s | duration=0.001s
# 581: Primary/P  1 | onset=1451.717s | duration=0.001s
# 582: Primary/P  1 | onset=1452.847s | duration=0.001s
# 583: Primary/P  1 | onset=1454.163s | duration=0.001s
# 584: Primary/P  1 | onset=1455.481s | duration=0.001s
# 585: Primary/P  1 | onset=1455.900s | duration=0.001s
# 586: Primary/P  1 | onset=1456.015s | duration=0.001s
# 587: Primary/P  1 | onset=1456.599s | duration=0.001s
# 588: Primary/P  1 | onset=1457.404s | duration=0.001s
# 589: Primary/P  1 | onset=1459.282s | duration=0.001s
# 590: Primary/P  1 | onset=1459.473s | duration=0.001s
# 591: Primary/P  1 | onset=1459.799s | duration=0.001s
# 592: Primary/P  1 | onset=1460.253s | duration=0.001s
# 593: Primary/P  1 | onset=1461.021s | duration=0.001s
# 594: Primary/P  1 | onset=1461.197s | duration=0.001s
# 595: Primary/P  1 | onset=1461.817s | duration=0.001s
# 596: Primary/P  1 | onset=1461.883s | duration=0.001s
# 597: Primary/P  1 | onset=1462.230s | duration=0.001s
# 598: Primary/P  1 | onset=1462.278s | duration=0.001s
# 599: Primary/P  1 | onset=1463.787s | duration=0.001s
# 600: Primary/P  1 | onset=1464.278s | duration=0.001s
# 601: Primary/P  1 | onset=1465.433s | duration=0.001s
# 602: Primary/P  1 | onset=1465.682s | duration=0.001s
# 603: Primary/P  1 | onset=1466.597s | duration=0.001s
# 604: Primary/P  1 | onset=1466.888s | duration=0.001s
# 605: Primary/P  1 | onset=1467.982s | duration=0.001s
# 606: Primary/P  1 | onset=1468.686s | duration=0.001s
# 607: Primary/P  1 | onset=1470.374s | duration=0.001s
# 608: Primary/P  1 | onset=1470.456s | duration=0.001s
# 609: Primary/P  1 | onset=1471.370s | duration=0.001s
# 610: Primary/P  1 | onset=1472.278s | duration=0.001s
# 611: Primary/P  1 | onset=1472.302s | duration=0.001s
# 612: Primary/P  1 | onset=1472.723s | duration=0.001s
# 613: Primary/P  1 | onset=1472.778s | duration=0.001s
# 614: Primary/P  1 | onset=1473.753s | duration=0.001s
# 615: Primary/P  1 | onset=1474.153s | duration=0.001s
# 616: Primary/P  1 | onset=1475.778s | duration=0.001s
# 617: Primary/P  1 | onset=1477.278s | duration=0.001s
# 618: Primary/P  1 | onset=1478.242s | duration=0.001s
# 619: Primary/P  1 | onset=1479.808s | duration=0.001s
# 620: Primary/P  1 | onset=1480.778s | duration=0.001s
# 621: Primary/P  1 | onset=1482.686s | duration=0.001s
# 622: Primary/P  1 | onset=1485.592s | duration=0.001s
# 623: Primary/P  1 | onset=1485.778s | duration=0.001s
# 624: Primary/P  1 | onset=1486.749s | duration=0.001s
# 625: Primary/P  1 | onset=1487.278s | duration=0.001s
# 626: Primary/P  1 | onset=1488.237s | duration=0.001s
# 627: Primary/P  1 | onset=1488.778s | duration=0.001s
# 628: Primary/P  1 | onset=1490.089s | duration=0.001s
# 629: Primary/P  1 | onset=1490.278s | duration=0.001s
# 630: Primary/P  1 | onset=1491.526s | duration=0.001s
# 631: Primary/P  1 | onset=1492.917s | duration=0.001s
# 632: Primary/P  1 | onset=1493.990s | duration=0.001s
# 633: Primary/P  1 | onset=1494.540s | duration=0.001s
# 634: Primary/P  1 | onset=1496.173s | duration=0.001s
# 635: Primary/P  1 | onset=1496.970s | duration=0.001s
# 636: Primary/P  1 | onset=1497.778s | duration=0.001s
# 637: Primary/P  1 | onset=1498.142s | duration=0.001s
# 638: Primary/P  1 | onset=1500.278s | duration=0.001s
# 639: Primary/P  1 | onset=1506.778s | duration=0.001s
# 640: Primary/P  1 | onset=1508.778s | duration=0.001s
# 641: Primary/P  1 | onset=1509.278s | duration=0.001s
# 642: Primary/P  1 | onset=1511.893s | duration=0.001s
# 643: Primary/P  1 | onset=1516.278s | duration=0.001s
# 644: Primary/P  1 | onset=1516.630s | duration=0.001s
# 645: Primary/P  1 | onset=1519.778s | duration=0.001s
# 646: Primary/P  1 | onset=1520.778s | duration=0.001s
# 647: Primary/P  1 | onset=1524.084s | duration=0.001s
# 648: Primary/P  1 | onset=1524.278s | duration=0.001s
# 649: Primary/P  1 | onset=1528.278s | duration=0.001s
# 650: Primary/P  1 | onset=1528.846s | duration=0.001s
# 651: Primary/P  1 | onset=1530.278s | duration=0.001s
# 652: Primary/P  1 | onset=1530.778s | duration=0.001s
# 653: Primary/P  1 | onset=1536.778s | duration=0.001s
# 654: Primary/P  1 | onset=1538.872s | duration=0.001s
# 655: Primary/P  1 | onset=1539.278s | duration=0.001s
# 656: Primary/P  1 | onset=1543.278s | duration=0.001s
# 657: Primary/P  1 | onset=1546.778s | duration=0.001s
# 658: Primary/P  1 | onset=1550.778s | duration=0.001s
# 659: Primary/P  1 | onset=1551.278s | duration=0.001s
# 660: Primary/P  1 | onset=1551.778s | duration=0.001s
# 661: Primary/P  1 | onset=1552.778s | duration=0.001s
# 662: Primary/P  1 | onset=1554.778s | duration=0.001s
# 663: Primary/P  1 | onset=1555.278s | duration=0.001s
# 664: Primary/P  1 | onset=1558.187s | duration=0.001s
# 665: Primary/P  1 | onset=1569.778s | duration=0.001s
# 666: Primary/P  1 | onset=1570.778s | duration=0.001s
# 667: Primary/P  1 | onset=1577.778s | duration=0.001s
# 668: Primary/P  1 | onset=1578.077s | duration=0.001s
# 669: Primary/P  1 | onset=1581.362s | duration=0.001s
# 670: Primary/P  1 | onset=1590.077s | duration=0.001s
# 671: Primary/P  1 | onset=1590.278s | duration=0.001s
# 672: Primary/P  1 | onset=1592.278s | duration=0.001s
# 673: Primary/P  1 | onset=1593.278s | duration=0.001s
# 674: Primary/P  1 | onset=1596.218s | duration=0.001s
# 675: Primary/P  1 | onset=1597.828s | duration=0.001s
# 676: Primary/P  1 | onset=1598.155s | duration=0.001s
# 677: Primary/P  1 | onset=1603.278s | duration=0.001s
# 678: Primary/P  1 | onset=1608.912s | duration=0.001s
# 679: Primary/P  1 | onset=1609.278s | duration=0.001s
# 680: Primary/P  1 | onset=1609.778s | duration=0.001s
# 681: Primary/P  1 | onset=1614.778s | duration=0.001s
# 682: Primary/P  1 | onset=1618.778s | duration=0.001s
# 683: Primary/P  1 | onset=1622.778s | duration=0.001s
# 684: Primary/P  1 | onset=1624.278s | duration=0.001s
# 685: Primary/P  1 | onset=1624.778s | duration=0.001s
# 686: Primary/P  1 | onset=1625.278s | duration=0.001s
# 687: Primary/P  1 | onset=1625.778s | duration=0.001s
# 688: Primary/P  1 | onset=1626.778s | duration=0.001s
# 689: Primary/P  1 | onset=1628.577s | duration=0.001s
# 690: Primary/P  1 | onset=1631.278s | duration=0.001s
# 691: Primary/P  1 | onset=1633.278s | duration=0.001s
# 692: Primary/P  1 | onset=1640.278s | duration=0.001s
# 693: Primary/P  1 | onset=1640.778s | duration=0.001s
# 694: Primary/P  1 | onset=1646.278s | duration=0.001s
# 695: Primary/P  1 | onset=1647.596s | duration=0.001s
# 696: Primary/P  1 | onset=1648.778s | duration=0.001s
# 697: Primary/P  1 | onset=1649.278s | duration=0.001s
# 698: Primary/P  1 | onset=1650.278s | duration=0.001s
# 699: Primary/P  1 | onset=1650.580s | duration=0.001s
# 700: Primary/P  1 | onset=1660.517s | duration=0.001s
# 701: Primary/P  1 | onset=1660.778s | duration=0.001s
# 702: Primary/P  1 | onset=1661.778s | duration=0.001s
# 703: Primary/P  1 | onset=1664.778s | duration=0.001s
# 704: Primary/P  1 | onset=1668.278s | duration=0.001s
# 705: Primary/P  1 | onset=1672.078s | duration=0.001s
# 706: Primary/P  1 | onset=1683.925s | duration=0.001s
# 707: Primary/P  1 | onset=1686.278s | duration=0.001s
# 708: Primary/P  1 | onset=1689.779s | duration=0.001s
# 709: Primary/P  1 | onset=1698.098s | duration=0.001s
# 710: Primary/P  1 | onset=1704.923s | duration=0.001s
# 711: Primary/P  1 | onset=1709.327s | duration=0.001s
# 712: Primary/P  1 | onset=1716.779s | duration=0.001s
# 713: Primary/P  1 | onset=1729.279s | duration=0.001s
# 714: Primary/P  1 | onset=1733.279s | duration=0.001s
# 715: Primary/P  1 | onset=1733.779s | duration=0.001s
# 716: Primary/P  1 | onset=1740.279s | duration=0.001s
# 717: Primary/P  1 | onset=1761.279s | duration=0.001s
# 718: Primary/P  1 | onset=1762.873s | duration=0.001s
# 719: Primary/P  1 | onset=1763.279s | duration=0.001s
# 720: Primary/P  1 | onset=1768.279s | duration=0.001s
# 721: Primary/P  1 | onset=1768.779s | duration=0.001s
# 722: Primary/P  1 | onset=1769.779s | duration=0.001s
# 723: Primary/P  1 | onset=1773.779s | duration=0.001s
# 724: Primary/P  1 | onset=1775.829s | duration=0.001s
# 725: Primary/P  1 | onset=1776.250s | duration=0.001s
# 726: Primary/P  1 | onset=1777.279s | duration=0.001s
# 727: Oddball_stop | onset=1777.779s | duration=0.001s
# Step 4 subsection start: 0.0
# Step 4 subsection end: 1569.14

# %% [markdown]
# ## 4. interactive plotly.

# %%
# Step 4: interactive Plotly/Dash EEG annotation interface.
#
# Processing order:
#   original EEG → 250 Hz resampling → 0.5–50 Hz filtering → common average reference
#
# This interface allows:
#   • box-selection of artifact intervals;
#   • clicking to select point events;
#   • automatic conversion from plot minutes to exact seconds;
#   • standardized annotation labels;
#   • ALL-channel or channel-specific annotations;
#   • undoing newly added annotations.
#
# Step 4 displays the physical-unit, average-referenced signal; global z-scoring happens only after section selection.

import importlib.util
import socket
import subprocess
import sys
import threading
import webbrowser
from datetime import datetime, timezone
from pathlib import Path
import json

import h5py

import numpy as np
import plotly.graph_objects as go

# Install Dash if it is not available.
if importlib.util.find_spec("dash") is None:

    print("Installing Dash...")

    subprocess.check_call(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "dash",
        ]
    )

from dash import (
    Dash,
    Input,
    Output,
    State,
    ctx,
    dash_table,
    dcc,
    html,
    no_update,
)
from werkzeug.serving import make_server

# ---------------------------------------------------------
# Prepare the filtered EEG.
# ---------------------------------------------------------

eeg_display = make_plotly_display_eeg(
    review,
    eeg,
)

data_filtered = eeg_display["data"]

channel_labels = list(
    eeg_display["labels"]
)

sampling_rate = float(
    eeg_display["srate"]
)

number_samples = int(
    eeg_display["n_samples"]
)

print(
    "Display filtering:",
    review["filtered"].info["highpass"],
    "to",
    review["filtered"].info["lowpass"],
    "Hz",
)

# High-variance candidates are detected on demand in the webpage.
_initial_display = data_filtered[:, ::max(1, int(round(sampling_rate)))].astype(float, copy=False)
_initial_robust_sd = 1.4826 * float(np.nanmedian(np.abs(_initial_display - np.nanmedian(_initial_display))))
HIGH_VARIANCE_CURRENT_ROBUST_SD = _initial_robust_sd


# ---------------------------------------------------------
# Downsample the average-referenced signal for browser visualization.
# ---------------------------------------------------------

MAX_DISPLAY_POINTS = 20000

display_step = max(
    1,
    int(
        np.ceil(
            number_samples
            / MAX_DISPLAY_POINTS
        )
    ),
)

display_samples = np.arange(
    0,
    number_samples,
    display_step,
)

time_minutes = (
    display_samples
    / sampling_rate
    / 60.0
)

data_to_plot = data_filtered[:, display_samples].astype(np.float32, copy=False) * 1e6

# Use a robust display limit so isolated artifacts do not make the EEG look flat.
DISPLAY_AMPLITUDE_LIMIT_UV = float(np.nanpercentile(np.abs(data_to_plot), 98.0))
if not np.isfinite(DISPLAY_AMPLITUDE_LIMIT_UV) or DISPLAY_AMPLITUDE_LIMIT_UV == 0:
    DISPLAY_AMPLITUDE_LIMIT_UV = 1.0

data_to_plot = np.clip(
    data_to_plot,
    -DISPLAY_AMPLITUDE_LIMIT_UV,
    DISPLAY_AMPLITUDE_LIMIT_UV,
)
# Keep the physical average-referenced display so z-score preview can be undone.
PHYSICAL_DATA_TO_PLOT = data_to_plot.copy()
STEP4_DISPLAY_MODE = "average-referenced µV"

OVERVIEW_DISPLAY_SAMPLES = display_samples.copy()
OVERVIEW_DISPLAY_AMPLITUDE_LIMIT_UV = DISPLAY_AMPLITUDE_LIMIT_UV
ADAPTIVE_FULL_RES_MAX_SECONDS = 180.0
STEP4_HIGH_RES_ACTIVE = False

def set_adaptive_display_window(start_minute=None, end_minute=None):
    """Use 250 Hz in a short focused interval; retain the overview otherwise."""
    global display_samples, time_minutes, data_to_plot, DISPLAY_AMPLITUDE_LIMIT_UV, CHANNEL_SPACING, offsets
    if start_minute is None or end_minute is None:
        display_samples = OVERVIEW_DISPLAY_SAMPLES.copy()
    else:
        start = max(0, int(np.floor(float(start_minute) * 60.0 * sampling_rate)))
        stop = min(number_samples, int(np.ceil(float(end_minute) * 60.0 * sampling_rate)))
        if stop <= start:
            return
        span = stop - start
        maximum = int(ADAPTIVE_FULL_RES_MAX_SECONDS * sampling_rate)
        step = max(1, int(np.ceil(span / maximum)))
        display_samples = np.arange(start, stop, step, dtype=int)
    time_minutes = display_samples / sampling_rate / 60.0
    if STEP4_DISPLAY_MODE == "global z-score" and STEP4_RECORDING_SCALE is not None:
        mean, std = STEP4_RECORDING_SCALE
        data_to_plot = ((data_filtered[:, display_samples] - mean) / std).astype(np.float32, copy=False)
        DISPLAY_AMPLITUDE_LIMIT_UV = max(3.0, float(np.nanpercentile(np.abs(data_to_plot), 98.0)))
    else:
        data_to_plot = data_filtered[:, display_samples].astype(np.float32, copy=False) * 1e6
        if start_minute is None or end_minute is None:
            DISPLAY_AMPLITUDE_LIMIT_UV = OVERVIEW_DISPLAY_AMPLITUDE_LIMIT_UV
        else:
            focused_limit = float(np.nanpercentile(np.abs(data_to_plot), 98.0))
            if np.isfinite(focused_limit) and focused_limit > 0:
                DISPLAY_AMPLITUDE_LIMIT_UV = focused_limit
    data_to_plot = np.clip(data_to_plot, -DISPLAY_AMPLITUDE_LIMIT_UV, DISPLAY_AMPLITUDE_LIMIT_UV)
    CHANNEL_SPACING = 2.5 * DISPLAY_AMPLITUDE_LIMIT_UV
    offsets = np.arange(number_channels)[::-1] * CHANNEL_SPACING

# Compact channel separation keeps the complete channel stack on one screen.
CHANNEL_SPACING = 2.5 * DISPLAY_AMPLITUDE_LIMIT_UV

number_channels = len(
    channel_labels
)

offsets = (
    np.arange(number_channels)[::-1]
    * CHANNEL_SPACING
)

# ---------------------------------------------------------
# High-contrast channel colors.
# ---------------------------------------------------------

CHANNEL_COLORS = {
    "FP1": "#0072B2",
    "FP2": "#D55E00",
    "F7": "#009E73",
    "F8": "#CC79A7",
    "T7": "#E69F00",
    "T8": "#56B4E9",
    "O1": "#222222",
    "O2": "#7B2CBF",
}

FALLBACK_COLORS = [
    "#0072B2",
    "#D55E00",
    "#009E73",
    "#CC79A7",
    "#E69F00",
    "#56B4E9",
    "#222222",
    "#7B2CBF",
]

top_of_plot = (
    offsets[0]
    + DISPLAY_AMPLITUDE_LIMIT_UV
)

bottom_of_plot = (
    offsets[-1]
    - DISPLAY_AMPLITUDE_LIMIT_UV
)

MARKER_LABEL_Y = (
    top_of_plot + 0.65 * DISPLAY_AMPLITUDE_LIMIT_UV
)
MAX_INTERVAL_OVERLAYS = 250
MAX_VISIBLE_MARKER_LABELS = 80

# Newly created Step 4 annotations are held here
# until Step 5 transfers them into the reviewed EEG.
STEP4_MANUAL_ANNOTATIONS = []

# Number already transferred to MNE.
STEP4_SYNCED_COUNT = 0
STEP4_DISPLAY_GAIN = 1.0
STEP4_HIGH_VARIANCE_CANDIDATES = []
STEP4_SHOW_MARKERS = False
STEP4_MARKER_VISIBLE_KEYS = None
STEP4_RECORDING_SCALE = None
STEP4_VIEW_START_MINUTE = None
STEP4_VIEW_END_MINUTE = None
# The focused interval is the only data Step 5 is allowed to process.
STEP4_FOCUSED_INTERVAL = None
# Exactly one interval can be assigned a context for the next Step 5 export.
STEP4_PROCESSING_SEGMENTS = []


def build_interactive_eeg_figure(display_gain=None):
    """Build the EEG figure with existing and newly added annotations."""

    if display_gain is None:
        display_gain = STEP4_DISPLAY_GAIN
    display_values = data_to_plot * float(display_gain)
    hover_value_label = "Global z-score" if STEP4_DISPLAY_MODE == "global z-score" else "Amplitude (µV)"
    display_top = offsets[0] + DISPLAY_AMPLITUDE_LIMIT_UV * float(display_gain)
    display_bottom = offsets[-1] - DISPLAY_AMPLITUDE_LIMIT_UV * float(display_gain)
    # Keep annotation labels visible above the traces at every display gain.
    display_marker_y = offsets[0] + 1.45 * DISPLAY_AMPLITUDE_LIMIT_UV

    figure = go.Figure()

    # Add EEG channels.
    for channel_index, channel_label in enumerate(
        channel_labels
    ):

        normalized_label = (
            channel_label
            .strip()
            .upper()
            .replace("EEG ", "")
        )

        channel_color = CHANNEL_COLORS.get(
            normalized_label,
            FALLBACK_COLORS[
                channel_index
                % len(FALLBACK_COLORS)
            ],
        )

        figure.add_trace(
            go.Scattergl(
                x=time_minutes,
                y=(
                    display_values[
                        channel_index
                    ]
                    + offsets[
                        channel_index
                    ]
                ),
                mode="lines",
                name=channel_label,
                line={
                    "width": 1.5,
                    "color": channel_color,
                },
                customdata=data_to_plot[
                    channel_index
                ],
                hovertemplate=(
                    f"<b>{channel_label}</b><br>"
                    "Time: %{x:.4f} min<br>"
                    f"{hover_value_label}: %{{customdata:.2f}}"
                    "<extra></extra>"
                ),
            )
        )

    # Combine imported annotations and new annotations.
    all_markers = []

    for marker in eeg_display["markers"]:

        all_markers.append(
            {
                "time_sec": float(
                    marker["time_sec"]
                ),
                "duration_sec": float(
                    marker.get(
                        "duration_sec",
                        0.0,
                    )
                ),
                "label": str(
                    marker["label"]
                ),
                "channels": marker.get(
                    "channels",
                    ["ALL"],
                ),
                "is_manual": False,
            }
        )

    # Standardized clinical/BAD annotations and all annotations made in this
    # session are always visible.  The marker table controls only dense raw
    # markers, so hiding oddball/stimulus streams never hides review decisions.
    imported_markers = all_markers
    all_markers.extend({**marker, "is_manual": True} for marker in STEP4_MANUAL_ANNOTATIONS)
    all_markers.extend({**marker, "is_manual": True} for marker in STEP4_HIGH_VARIANCE_CANDIDATES)
    for marker_index, marker in enumerate(all_markers):
        marker["marker_key"] = f"marker:{marker_index}"
    always_visible = [
        marker for marker in all_markers
        if marker.get("is_manual")
        or str(marker.get("label", "")) in STANDARD_LABELS
        or str(marker.get("label", "")).startswith("BAD_")
    ]
    if STEP4_SHOW_MARKERS:
        selected_raw = imported_markers
        if STEP4_MARKER_VISIBLE_KEYS is not None:
            selected_raw = [marker for marker in imported_markers if marker["marker_key"] in STEP4_MARKER_VISIBLE_KEYS]
        known = {marker["marker_key"] for marker in always_visible}
        all_markers = always_visible + [marker for marker in selected_raw if marker["marker_key"] not in known]
    else:
        all_markers = always_visible

    def visible_subset(markers, maximum):
        """Keep labels representative and responsive for dense event streams."""
        manual = [marker for marker in markers if marker.get("is_manual")]
        imported = [marker for marker in markers if not marker.get("is_manual")]
        remaining = max(0, maximum - len(manual))
        if len(imported) <= remaining:
            return manual + imported
        selected_indices = np.linspace(0, len(imported) - 1, remaining, dtype=int)
        return manual + [imported[index] for index in selected_indices]

    # Render all point annotations in one WebGL trace. This avoids creating
    # thousands of Plotly shapes and labels for dense imported event streams.
    point_markers = [
        marker for marker in all_markers
        if float(marker.get("duration_sec", 0.0)) <= 0
    ]
    if point_markers:
        # A single WebGL line trace makes selected events unmistakable even in a
        # whole-recording overview, without creating one Plotly shape per event.
        marker_x, marker_y = [], []
        marker_top = offsets[0] + 2.0 * DISPLAY_AMPLITUDE_LIMIT_UV
        marker_bottom = offsets[-1] - 1.0 * DISPLAY_AMPLITUDE_LIMIT_UV
        for marker in point_markers:
            marker_time = float(marker["time_sec"]) / 60.0
            marker_x.extend([marker_time, marker_time, None])
            marker_y.extend([marker_bottom, marker_top, None])
        figure.add_trace(go.Scattergl(
            x=marker_x, y=marker_y, mode="lines", hoverinfo="skip",
            line={"width": 1.2, "color": "crimson"}, showlegend=False,
        ))
        figure.add_trace(go.Scatter(
            x=[float(marker["time_sec"]) / 60.0 for marker in point_markers],
            y=[display_marker_y] * len(point_markers), mode="markers",
            marker={"size": 7, "color": "crimson", "symbol": "circle"},
            customdata=[f"{marker['label']} [{','.join(marker.get('channels', ['ALL']))}]" for marker in point_markers],
            hovertemplate="Point annotation<br>Time: %{x:.4f} min<br>%{customdata}<extra></extra>",
            showlegend=False,
        ))

    # Labels are always visible for manually added markers. Imported labels are
    # evenly sampled when there are many, while every marker remains hoverable.
    label_markers = visible_subset(all_markers, MAX_VISIBLE_MARKER_LABELS)
    if label_markers:
        figure.add_trace(
            go.Scatter(
                x=[float(marker["time_sec"]) / 60.0 for marker in label_markers],
                y=[display_marker_y] * len(label_markers),
                mode="markers+text",
                marker={"size": 7, "color": "crimson"},
                text=[
                    f"{marker['label']} [{','.join(marker.get('channels', []))}]"
                    if str(marker["label"]) == "BAD_channel" and marker.get("channels")
                    else str(marker["label"])
                    for marker in label_markers
                ],
                textposition="top center",
                textfont={"color": "crimson", "size": 10},
                hovertemplate=(
                    "Annotation: %{text}<br>Time: %{x:.4f} min"
                    "<extra></extra>"
                ),
                cliponaxis=False,
            )
        )

    # Interval annotations retain their shaded spans and labels.
    interval_markers = [
        marker for marker in all_markers
        if float(marker.get("duration_sec", 0.0)) > 0
    ]
    for marker in visible_subset(interval_markers, MAX_INTERVAL_OVERLAYS):

        marker_time_sec = float(
            marker["time_sec"]
        )

        marker_duration_sec = float(
            marker.get(
                "duration_sec",
                0.0,
            )
        )

        marker_time_min = (
            marker_time_sec / 60.0
        )

        marker_label = str(
            marker["label"]
        )

        if marker_duration_sec <= 0:
            continue

        if marker_duration_sec > 0:

            marker_end_min = (
                marker_time_sec
                + marker_duration_sec
            ) / 60.0

            if marker_label.startswith(
                "BAD_"
            ):

                fill_color = (
                    "rgba(255, 0, 0, 0.15)"
                )

            elif marker_label.startswith(
                "CLEAN_"
            ):

                fill_color = (
                    "rgba(0, 170, 0, 0.10)"
                )

            else:

                fill_color = (
                    "rgba(30, 100, 255, 0.10)"
                )

            marker_channels = list(marker.get("channels", []))
            # Accept both stored channel lists and labels such as
            # ``BAD_channel [P3]`` from previously organized files.
            if str(marker_label).startswith("BAD_channel") and (not marker_channels or "ALL" in marker_channels):
                import re
                bracket_match = re.search(r"\[([^\]]+)\]", str(marker_label))
                if bracket_match:
                    marker_channels = [value.strip() for value in bracket_match.group(1).split(",") if value.strip()]
            if str(marker_label).startswith("BAD_channel") and marker_channels and "ALL" not in marker_channels:
                # Channel-specific bad marking: shade only the affected rows,
                # rather than implying that every channel is bad.
                normalized_channels = {str(name).strip().casefold(): index for index, name in enumerate(channel_labels)}
                for affected_channel in marker_channels:
                    channel_index = normalized_channels.get(str(affected_channel).strip().casefold())
                    if channel_index is None:
                        continue
                    figure.add_shape(
                        type="rect", xref="x", yref="y",
                        x0=marker_time_min, x1=marker_end_min,
                        y0=offsets[channel_index] - 0.42 * CHANNEL_SPACING,
                        y1=offsets[channel_index] + 0.42 * CHANNEL_SPACING,
                        fillcolor=fill_color, line_width=0, layer="below",
                    )
            else:
                figure.add_vrect(
                    x0=marker_time_min,
                    x1=marker_end_min,
                    fillcolor=fill_color,
                    line_width=0,
                    layer="below",
                )

        figure.add_vline(
            x=marker_time_min,
            line_color="red",
            line_dash="dash",
            line_width=1,
            opacity=0.65,
        )

    figure.update_layout(
        title=(
            "EEG review — " + STEP4_DISPLAY_MODE + ": drag a box for an interval "
            "or click for a point event"
        ),
        xaxis_title=(
            "Time from beginning of recording "
            "(minutes)"
        ),
        yaxis={
            "title": "Channels (global z-score)" if STEP4_DISPLAY_MODE == "global z-score" else "Channels (average-referenced µV)",
            "tickmode": "array",
            "tickvals": offsets,
            "ticktext": channel_labels,
            # Keep channel baseline positions fixed as display gain changes.
        "range": [
                offsets[-1] - 1.25 * DISPLAY_AMPLITUDE_LIMIT_UV,
                offsets[0] + 2.25 * DISPLAY_AMPLITUDE_LIMIT_UV,
            ],
        },
        height=max(630, 60 * number_channels),
        hovermode="closest",
        showlegend=False,
        dragmode="select",
        clickmode="event+select",
        uirevision="keep-eeg-view",
        plot_bgcolor="white",
        paper_bgcolor="white",
        margin={
            "l": 110,
            "r": 30,
            "t": 85,
            "b": 60,
        },
    )

    figure.update_xaxes(
        title="Time from recording start (minutes; dashed minor grid = 1 second)",
        showgrid=True,
        gridcolor="rgba(180, 180, 180, 0.25)",
        griddash="solid",
        showticklabels=True,
        ticks="outside",
        rangeslider={"visible": True, "thickness": 0.06},
        range=(
            [STEP4_VIEW_START_MINUTE, STEP4_VIEW_END_MINUTE]
            if STEP4_VIEW_START_MINUTE is not None
            else None
        ),
        minor={
            "dtick": 1.0 / 60.0,
            "showgrid": True,
            "gridcolor": "rgba(110, 110, 110, 0.38)",
            "griddash": "dash",
        },
    )

    figure.update_yaxes(
        showgrid=False,
    )

    return figure


# ---------------------------------------------------------
# Create the Dash application.
# ---------------------------------------------------------

step4_app = Dash(
    __name__,
)

channel_options = [
    {
        "label": "ALL channels",
        "value": "ALL",
    }
]

channel_options.extend(
    {
        "label": channel,
        "value": channel,
    }
    for channel in channel_labels
)

label_options = [{"label": label, "value": label} for label in STANDARD_LABELS]
existing_annotation_options = [
    {"label": f"{float(onset):.3f} sec — {description}", "value": str(index)}
    for index, (onset, description) in enumerate(zip(review["master"].annotations.onset, review["master"].annotations.description))
]

PROCESSING_CONTEXTS = ["preop1", "preop2", "or1", "or2", "or3", "or4", "or5"]
ALLOWED_CHANNEL_NAMES = ["Fp1", "Fp2", "F3", "F4", "FC1", "FC2", "C3", "C4", "Fz", "Cz", "P3", "P4", "O1", "O2"]

step4_app.layout = html.Div([
    dcc.Location(id="step4-main-location"),
    html.Div([
        html.Div([
html.H3("Recording-wide normalization"),
            html.Label(f"Exclude samples above robust z-score threshold when fitting (current robust SD = {HIGH_VARIANCE_CURRENT_ROBUST_SD:.3e})"),
            dcc.Input(id="high-variance-threshold", type="number", value=3.0, min=0.5, step=0.5, style={"width":"100%"}),
            html.Div("This controls the scale fit only; it does not create annotations or clip the saved EEG.", style={"fontSize":"11px", "marginTop":"4px"}),
            html.Button("Preview global z-score", id="preview-zscore", n_clicks=0, style={"marginTop":"6px"}), html.Button("Show average reference", id="show-average-reference", n_clicks=0, style={"marginLeft":"6px"}), html.Div(id="zscore-preview-status", style={"marginTop":"4px","fontSize":"11px"}),
            html.Hr(), html.H3("Focused interval"),
            html.Div([html.Button("Focus selected interval", id="focus-selected-interval", n_clicks=0), html.Button("Show full recording", id="show-full-recording", n_clicks=0, style={"marginLeft": "6px"}), html.Button("Clear focus selection", id="clear-focus-selection", n_clicks=0, style={"marginLeft": "6px"})]),
            html.Div([dcc.Input(id="start-minutes", type="number", step=0.0001, placeholder="Start min", style={"width": "48%"}), dcc.Input(id="end-minutes", type="number", step=0.0001, placeholder="End min", style={"width": "48%", "marginLeft": "4%"})], style={"marginTop": "8px"}),
            html.Div(id="selection-status", children="Drag an interval in the EEG plot, then focus it.", style={"marginTop": "8px", "fontSize": "12px"}),
            html.Hr(), html.Label("Display gain"),
            html.Div([html.Button("− ×0.5", id="decrease-display-gain", n_clicks=0), html.Button("+ ×2", id="increase-display-gain", n_clicks=0, style={"marginLeft": "6px"}), html.Button("Reset gain / full view", id="reset-display-gain", n_clicks=0, style={"marginLeft": "6px"}), html.Button(f"Switch to {sampling_rate:g} Hz view", id="toggle-full-rate-view", n_clicks=0, style={"marginTop": "6px"})]),
            html.Div(id="action-status", style={"marginTop": "8px", "fontWeight": "bold", "fontSize": "12px"}),
        ], style={"width": "300px", "padding": "10px", "border": "1px solid #ccc", "borderRadius": "6px", "backgroundColor": "#fafafa"}),
        html.Div([dcc.Graph(id="eeg-graph", figure=build_interactive_eeg_figure(), config={"displaylogo": False, "scrollZoom": True, "doubleClick": "reset+autosize", "responsive": True, "modeBarButtonsToRemove": ["lasso2d"]}, style={"height": f"{max(630, 60 * number_channels)}px"})], style={"flex": "1", "minWidth": "0"}),
    ], style={"display": "flex", "gap": "10px", "alignItems": "stretch"}),
    html.Div([
        html.Div([
            html.H4("Bad channels"),
            html.Div("Set global bad channels before previewing or packaging. Choose focused interval only after focusing an interval.", style={"fontSize": "11px", "marginBottom": "5px"}),
            dcc.RadioItems(id="bad-channel-scope", options=[{"label": "Global", "value": "global"}, {"label": "Focused interval only", "value": "focused"}], value="global"),
            dcc.Dropdown(id="bad-channel-selection", options=[{"label": value, "value": value} for value in channel_labels], value=[], multi=True, placeholder="Select channels", style={"marginTop": "6px"}),
            html.Div([html.Button("Set bad", id="set-bad-channels", n_clicks=0), html.Button("Clear global", id="clear-bad-channels", n_clicks=0, style={"marginLeft": "6px"})], style={"marginTop": "6px"}),
            html.Div(id="bad-channel-status", style={"fontSize": "11px", "marginTop": "6px"}),
        ]),
        html.Div([
            html.H4("Add annotation"),
            dcc.RadioItems(id="annotation-kind", options=[{"label": "Interval", "value": "interval"}, {"label": "Point", "value": "point"}], value="interval", inline=True),
            dcc.Dropdown(id="standard-label", options=label_options, value="BAD_movement", clearable=False, style={"marginTop": "6px"}),
            dcc.Dropdown(id="affected-channels", options=channel_options, value=["ALL"], multi=True, placeholder="Affected channels", style={"marginTop": "6px"}),
            html.Div([html.Button("Add", id="add-annotation", n_clicks=0), html.Button("Undo", id="undo-annotation", n_clicks=0, style={"marginLeft": "6px"})], style={"marginTop": "6px"}),
        ]),
        html.Div([
            html.H4("Standardize / rename"),
            dcc.Dropdown(id="replace-annotation-index", options=existing_annotation_options, placeholder="Existing annotation"),
            dcc.Dropdown(id="replace-annotation-label", options=label_options, value="BAD_movement", clearable=False, style={"marginTop": "6px"}),
            html.Button("Replace label", id="replace-annotation", n_clicks=0, style={"marginTop": "6px"}), html.Button("Delete label", id="delete-annotation", n_clicks=0, style={"marginLeft": "6px"}), html.Div(id="replace-annotation-status", style={"fontSize": "11px"}),
            dcc.Input(id="batch-delete-search", type="text", placeholder="Search text (blank = duplicate-label suggestions)", style={"width":"100%","marginTop":"6px"}),
            html.Button("Find / suggest", id="batch-delete-find", n_clicks=0), html.Button("Delete selected", id="batch-delete-confirm", n_clicks=0, style={"marginLeft":"6px"}),
            dcc.Checklist(id="batch-delete-selection", options=[], value=[], style={"fontSize":"11px", "maxHeight":"82px", "overflowY":"auto", "marginTop":"4px"}),
            dcc.Checklist(id="batch-delete-ok", options=[{"label":"I confirm batch deletion","value":"yes"}], value=[], style={"fontSize":"11px"}), html.Div(id="batch-delete-status", children="Search text, or click Find / suggest with blank text to list duplicate labels.", style={"fontSize":"11px"}),
            dcc.Dropdown(id="channel-rename-source", options=[{"label": value, "value": value} for value in channel_labels], value=channel_labels[0] if channel_labels else None, clearable=False, style={"marginTop": "8px"}),
            dcc.Dropdown(id="channel-rename-target", options=[{"label": value, "value": value} for value in ALLOWED_CHANNEL_NAMES], value="Fp1", clearable=False, style={"marginTop": "6px"}),
            html.Button("Rename channel", id="apply-channel-rename", n_clicks=0, style={"marginTop": "6px"}), html.Div(id="channel-rename-status", style={"fontSize": "11px"}),
        ]),
        html.Div([
            html.H4("Package interval (focused, or whole recording)"),
            dcc.Input(id="package-participant", type="text", value="L000", placeholder="Participant ID", style={"width": "100%"}),
            dcc.Input(id="package-reviewer", type="text", placeholder="Reviewer initials", style={"width": "100%", "marginTop": "6px"}),
            dcc.Dropdown(id="processing-section-context", options=[{"label": value, "value": value} for value in PROCESSING_CONTEXTS], value="or1", clearable=False, style={"marginTop": "6px"}),
            dcc.Checklist(id="replace-existing-context", options=[{"label": "I confirm: replace existing context", "value": "replace"}], value=[], style={"marginTop": "6px", "fontSize": "11px"}),
            html.Button("Confirm, z-score, add to patient package", id="confirm-package-interval", n_clicks=0, style={"marginTop": "6px", "fontWeight": "bold"}),
            html.Div(id="package-status", children="", style={"fontSize": "11px", "marginTop": "6px"}),
        ]),
    ], style={"display": "grid", "gridTemplateColumns": "repeat(4, minmax(0, 1fr))", "alignItems": "start", "gap": "10px", "marginTop": "10px"}),

    html.Div(id="step4-marker-panel", children=[
        html.H4("Markers to display"),
        html.Div("Search by label, time, or channel; then select rows and click Display selected.", style={"fontSize":"12px", "marginBottom":"5px"}),
        dcc.Input(id="step4-marker-search", type="text", debounce=True, placeholder="Search markers (e.g., oddball, stimulus, 120.5)", style={"width":"100%", "marginBottom":"6px"}),
        dash_table.DataTable(
            id="step4-marker-table",
            columns=[{"name": x, "id": x} for x in ["time_sec", "duration_sec", "label", "channels"]],
            data=[{"key": f"marker:{index}", "time_sec": round(float(marker["time_sec"]), 4), "duration_sec": round(float(marker.get("duration_sec", 0)), 4), "label": str(marker["label"]), "channels": ",".join(marker.get("channels", ["ALL"]))} for index, marker in enumerate(eeg_display["markers"])],
            row_selectable="multi", selected_rows=[], virtualization=True, filter_action="native",
            fixed_rows={"headers": True}, style_table={"height": "240px", "overflowY": "auto"},
        ),
        html.Button("Select matching", id="step4-marker-select-matching", n_clicks=0, style={"marginTop":"6px"}), html.Button("Deselect matching", id="step4-marker-deselect-matching", n_clicks=0, style={"marginLeft":"8px", "marginTop":"6px"}), html.Button("Display selected", id="step4-marker-display", n_clicks=0, style={"marginLeft":"8px", "marginTop":"6px"}),
        html.Button("Select all", id="step4-marker-all", n_clicks=0, style={"marginLeft":"8px", "marginTop":"6px"}),
        html.Button("Clear selection / hide", id="step4-marker-close", n_clicks=0, style={"marginLeft":"8px", "marginTop":"6px"}),
        html.Div(id="step4-marker-status", style={"fontSize":"12px", "marginTop":"5px"}),
    ], style={"marginTop":"10px", "padding":"10px", "border":"1px solid #ccc", "borderRadius":"6px", "backgroundColor":"#fafafa"}),

    dash_table.DataTable(id="manual-annotation-table", columns=[], data=[], style_table={"display": "none"}),
    dash_table.DataTable(id="processing-section-table", columns=[], data=[], style_table={"display": "none"}),
    html.Button(id="add-processing-section", n_clicks=0, style={"display": "none"}),
    html.Button(id="undo-processing-section", n_clicks=0, style={"display": "none"}),
    html.Div(id="processing-section-status", style={"display": "none"}),
], style={"fontFamily": "Arial, sans-serif", "padding": "10px", "maxWidth": "100vw", "boxSizing": "border-box"})

def _package_focused_interval(participant, reviewer, context, allow_replace=False, robust_z_threshold=3.0):
    """Write the focused interval, or the full recording when none is focused."""
    global STEP4_SYNCED_COUNT
    participant = str(participant or "").strip().upper()
    reviewer = str(reviewer or "").strip()
    if not __import__("re").fullmatch(r"L[0-9]{3,}", participant):
        raise ValueError("Participant must be deidentified, for example L0123.")
    if not __import__("re").fullmatch(r"[A-Za-z0-9_-]{1,20}", reviewer):
        raise ValueError("Reviewer ID must be 1–20 letters, numbers, _ or -.")
    for annotation in STEP4_MANUAL_ANNOTATIONS[STEP4_SYNCED_COUNT:]:
        channels = [] if "ALL" in annotation["channels"] else list(annotation["channels"])
        for raw_key in ("master", "filtered", "display"):
            review[raw_key].annotations.append(onset=[float(annotation["time_sec"])], duration=[float(annotation["duration_sec"])], description=[str(annotation["label"])], ch_names=[channels])
    STEP4_SYNCED_COUNT = len(STEP4_MANUAL_ANNOTATIONS)

    filtered = review["filtered"].copy().load_data()
    master = review["master"]
    sampling_rate = float(filtered.info["sfreq"])
    if STEP4_FOCUSED_INTERVAL:
        start_sec = float(STEP4_FOCUSED_INTERVAL["start_sec"])
        end_sec = float(STEP4_FOCUSED_INTERVAL["end_sec"])
    else:
        start_sec = 0.0
        end_sec = float(filtered.n_times / sampling_rate)
    start_sample = max(0, int(round(start_sec * sampling_rate)))
    end_sample = min(filtered.n_times, int(round(end_sec * sampling_rate)))
    data = filtered.get_data(start=start_sample, stop=end_sample).astype(float)
    if data.shape[1] == 0:
        raise ValueError("Selected interval has no samples.")
    mean, std, fit_channels, fit_points = recording_wide_global_scale(robust_z_threshold)
    if not np.isfinite(std) or std == 0:
        raise ValueError("Recording-wide global standard deviation is invalid.")
    zdata = ((data - mean) / std).astype(np.float32)

    export_folder = Path(globals().get("EXPORT_FOLDER", Path.cwd() / "reviewed_eeg"))
    export_folder.mkdir(parents=True, exist_ok=True)
    package = export_folder / f"{participant}_reviewed_eeg.h5"
    text_type = h5py.string_dtype(encoding="utf-8")
    with h5py.File(package, "a") as h5:
        h5.attrs["format_name"] = "Anesthesia EEG participant package"
        h5.attrs["participant_id"] = participant
        recordings = h5.require_group("recordings")
        if context in recordings:
            if not allow_replace:
                raise ValueError(f"{context} is already in this patient package. Tick replacement confirmation to replace it.")
            del recordings[context]
        recording = recordings.create_group(context)
        recording.attrs["source_start_sec"] = start_sec
        recording.attrs["source_end_sec"] = end_sec
        recording.attrs["reviewer"] = reviewer
        recording.attrs["packaged_utc"] = datetime.now(timezone.utc).isoformat()
        eeg_group = recording.create_group("eeg")
        eeg_group.create_dataset("data_average_referenced_global_zscore", data=zdata, compression="gzip", compression_opts=4, shuffle=True, chunks=(1, max(1, min(zdata.shape[1], int(sampling_rate * 10)))))
        eeg_group.attrs["sampling_frequency_hz"] = sampling_rate
        eeg_group.attrs["reference"] = "common average across all EEG channels"
        eeg_group.attrs["normalization"] = "recording-wide global z-score fit on global good channels and non-BAD one-second points"
        eeg_group.attrs["global_mean_volts"] = mean
        eeg_group.attrs["global_std_volts"] = std
        eeg_group.attrs["recording_wide_robust_z_fit_threshold"] = float(robust_z_threshold)
        eeg_group.attrs["recording_wide_global_zscore_fit_channels"] = fit_channels
        eeg_group.attrs["recording_wide_global_zscore_fit_points"] = fit_points
        eeg_group.create_dataset("channel_labels", data=np.asarray(master.ch_names, dtype=object), dtype=text_type)
        eeg_group.create_dataset("globally_bad_channels", data=np.asarray(master.info["bads"], dtype=object), dtype=text_type)
        annotations = recording.create_group("annotations")
        rows=[]
        for onset, duration, label, channels in zip(master.annotations.onset, master.annotations.duration, master.annotations.description, master.annotations.ch_names):
            onset, duration = float(onset), float(duration); end = onset + duration
            if (duration == 0 and not start_sec <= onset < end_sec) or (duration > 0 and (end <= start_sec or onset >= end_sec)):
                continue
            clipped = max(onset, start_sec)
            rows.append((clipped-start_sec, 0.0 if duration == 0 else min(end, end_sec)-clipped, str(label), ",".join(channels) if channels else "all"))
        annotations.create_dataset("onset_sec", data=np.asarray([r[0] for r in rows], dtype=float))
        annotations.create_dataset("duration_sec", data=np.asarray([r[1] for r in rows], dtype=float))
        annotations.create_dataset("label", data=np.asarray([r[2] for r in rows], dtype=object), dtype=text_type)
        annotations.create_dataset("channels", data=np.asarray([r[3] for r in rows], dtype=object), dtype=text_type)
        h5.attrs["n_recordings"] = len(recordings)
    return package, False



STEP4_MAIN_LAYOUT = step4_app.layout

def refresh_step4_main_page():
    """Update the main-page components before Dash serializes the layout."""
    def walk(component):
        if getattr(component, "id", None) == "eeg-graph":
            component.figure = build_interactive_eeg_figure()
        elif getattr(component, "id", None) == "step4-show-markers":
            component.value = ["show"] if STEP4_SHOW_MARKERS else []
        children = getattr(component, "children", None)
        if isinstance(children, (list, tuple)):
            for child in children:
                if child is not None:
                    walk(child)
        elif children is not None:
            walk(children)
    walk(STEP4_MAIN_LAYOUT)

# Keep a static Dash layout: rebuilding the large EEG figure for every server
# validation request makes long recordings unnecessarily slow to open.
step4_app.layout = STEP4_MAIN_LAYOUT

def step4_marker_rows():
    markers=[]
    for index, marker in enumerate(eeg_display["markers"]): markers.append({"key":f"marker:{index}","time_sec":round(float(marker["time_sec"]),4),"duration_sec":round(float(marker.get("duration_sec",0)),4),"label":str(marker["label"]),"channels":",".join(marker.get("channels",["ALL"]))})
    return markers

def all_step4_marker_rows():
    return [
        {"key": f"marker:{index}", "time_sec": round(float(marker["time_sec"]), 4),
         "duration_sec": round(float(marker.get("duration_sec", 0)), 4),
         "label": str(marker["label"]), "channels": ",".join(marker.get("channels", ["ALL"]))}
        for index, marker in enumerate(eeg_display["markers"])
    ]

@step4_app.callback(
    Output("step4-marker-table", "data"),
    Output("step4-marker-table", "selected_rows"),
    Output("step4-marker-status", "children"),
    Output("eeg-graph", "figure", allow_duplicate=True),
    Input("step4-marker-search", "value"),
    Input("step4-marker-select-matching", "n_clicks"),
    Input("step4-marker-deselect-matching", "n_clicks"),
    Input("step4-marker-display", "n_clicks"),
    Input("step4-marker-all", "n_clicks"),
    Input("step4-marker-close", "n_clicks"),
    State("step4-marker-table", "data"),
    State("step4-marker-table", "selected_rows"),
    prevent_initial_call=True,
)
def display_step4_markers_inline(search_text, select_matching, deselect_matching, display_clicks, all_clicks, clear_clicks, rows, selected_rows):
    global STEP4_SHOW_MARKERS, STEP4_MARKER_VISIBLE_KEYS
    selected_keys = globals().setdefault("STEP4_MARKER_TABLE_SELECTED_KEYS", set())
    rows = list(rows or [])
    current_keys = {rows[index]["key"] for index in (selected_rows or []) if 0 <= index < len(rows)}
    selected_keys.update(current_keys)
    if ctx.triggered_id == "step4-marker-search":
        query = str(search_text or "").strip().casefold()
        filtered = [row for row in all_step4_marker_rows() if not query or query in " ".join(str(row[field]) for field in ("time_sec", "duration_sec", "label", "channels")).casefold()]
        selected = [index for index, row in enumerate(filtered) if row["key"] in selected_keys]
        return filtered, selected, f"{len(filtered):,} matching markers; {len(selected)} remain selected.", no_update
    if ctx.triggered_id == "step4-marker-all":
        selected_keys.clear(); selected_keys.update(row["key"] for row in all_step4_marker_rows())
        selected = [index for index, row in enumerate(rows) if row["key"] in selected_keys]
        return rows, selected, f"Selected all {len(selected_keys):,} markers. Search duplicate labels, then click Deselect matching.", no_update
    if ctx.triggered_id == "step4-marker-select-matching":
        selected_keys.update(row["key"] for row in rows)
        return rows, list(range(len(rows))), f"Selected {len(rows)} matching markers.", no_update
    if ctx.triggered_id == "step4-marker-deselect-matching":
        selected_keys.difference_update(row["key"] for row in rows)
        return rows, [], f"Deselected {len(rows)} matching markers; {len(selected_keys):,} markers remain selected.", no_update
    if ctx.triggered_id == "step4-marker-close":
        selected_keys.clear(); STEP4_SHOW_MARKERS = False; STEP4_MARKER_VISIBLE_KEYS = None
        return rows, [], "Marker display cleared.", build_interactive_eeg_figure()
    if not selected_keys:
        return rows, list(selected_rows or []), "Select markers first (or Select all, then deselect search results).", no_update
    STEP4_MARKER_VISIBLE_KEYS = set(selected_keys); STEP4_SHOW_MARKERS = True
    return rows, [index for index, row in enumerate(rows) if row["key"] in selected_keys], f"Displaying {len(selected_keys):,} selected markers.", build_interactive_eeg_figure()


# Rename labels in every raw object so the Step 5 file uses the new names.
@step4_app.callback(
    Output("eeg-graph", "figure", allow_duplicate=True),
    Output("affected-channels", "options"),
    Output("channel-rename-source", "options"),
    Output("channel-rename-status", "children"),
    Input("apply-channel-rename", "n_clicks"),
    State("channel-rename-source", "value"),
    State("channel-rename-target", "value"),
    prevent_initial_call=True,
)
def rename_channel_for_recording(clicks, old_name, new_name):
    global channel_labels, channel_options
    if not old_name or not new_name or old_name not in channel_labels:
        return no_update, no_update, no_update, "Choose a current channel and a replacement."
    if old_name == new_name:
        return no_update, no_update, no_update, "That channel already has this name."
    if new_name in channel_labels:
        return no_update, no_update, no_update, f"{new_name} is already assigned."
    for raw_key in ("master", "filtered", "display"):
        review[raw_key].rename_channels({old_name: new_name})
    channel_labels[channel_labels.index(old_name)] = new_name
    for annotation in STEP4_MANUAL_ANNOTATIONS:
        annotation["channels"] = [new_name if value == old_name else value for value in annotation["channels"]]
    channel_options = [{"label": "ALL channels", "value": "ALL"}] + [{"label": value, "value": value} for value in channel_labels]
    source_options = [{"label": value, "value": value} for value in channel_labels]
    return build_interactive_eeg_figure(), channel_options, source_options, f"Renamed {old_name} to {new_name} for the whole recording."




def detect_high_variance_candidates(threshold, density):
    """Detect 1-sec blocks by either dense high-amplitude points or high variance."""
    raw = review["filtered"].copy().load_data()
    values = raw.get_data().astype(float)
    amplitude = np.nanpercentile(np.abs(values), 75.0, axis=0)
    median = float(np.nanmedian(amplitude)); mad = float(np.nanmedian(np.abs(amplitude - median)))
    robust_sd = 1.4826 * mad
    point_flagged = amplitude > median + float(threshold) * robust_sd if robust_sd > 0 else np.zeros(amplitude.size, dtype=bool)
    sfreq = float(raw.info["sfreq"]); block = max(1, int(round(sfreq)))
    block_variance=[]
    for left in range(0, values.shape[1], block):
        right=min(values.shape[1],left+block)
        block_variance.append(float(np.nanmedian(np.nanstd(values[:,left:right],axis=1))))
    block_variance=np.asarray(block_variance)
    variance_median=float(np.nanmedian(block_variance)); variance_mad=float(np.nanmedian(np.abs(block_variance-variance_median)))
    variance_threshold=variance_median + float(threshold)*1.4826*variance_mad
    selected=np.zeros(point_flagged.size,dtype=bool); amplitude_blocks=0; variance_blocks=0
    for block_index,left in enumerate(range(0,point_flagged.size,block)):
        right=min(point_flagged.size,left+block)
        dense=point_flagged[left:right].mean() >= float(density)
        variable=block_variance[block_index] > variance_threshold if variance_mad > 0 else False
        if dense or variable:
            selected[left:right]=True
            amplitude_blocks += int(dense); variance_blocks += int(variable)
    globals()["STEP4_HIGH_VARIANCE_DIAGNOSTICS"]={"amplitude_blocks":amplitude_blocks,"variance_blocks":variance_blocks,"max_amplitude_robust_z":float((np.nanmax(amplitude)-median)/robust_sd) if robust_sd>0 else float("nan"),"max_variance_robust_z":float((np.nanmax(block_variance)-variance_median)/(1.4826*variance_mad)) if variance_mad>0 else float("nan")}
    runs=[]; run_start=None
    for index,value in enumerate(np.r_[selected,False]):
        if value and run_start is None: run_start=index
        if not value and run_start is not None:
            runs.append({"time_sec":round(run_start/sfreq,3),"duration_sec":round((index-run_start)/sfreq,3),"label":"BAD_high_variance","channels":["ALL"]}); run_start=None
    return runs


def recording_wide_global_scale(robust_z_threshold=3.0):
    """Fit one global mean/SD after excluding current bad channels and samples.

    Global bad channels are removed entirely.  ``BAD_*`` annotations remove all
    channels in their intervals; channel-specific ``BAD_channel`` annotations
    remove only the named channels during their marked interval.
    """
    threshold = float(robust_z_threshold or 3.0)
    if not np.isfinite(threshold) or threshold <= 0:
        raise ValueError("Robust z-score threshold must be a positive number.")
    fit_indices = np.arange(0, number_samples, max(1, int(round(sampling_rate))), dtype=int)
    fit_times = fit_indices / float(sampling_rate)
    values = data_filtered[:, fit_indices].astype(float, copy=False)
    global_bad = set(review["master"].info["bads"])
    good_indices = [index for index, name in enumerate(channel_labels) if name not in global_bad]
    if not good_indices:
        raise ValueError("No global good channels remain for recording-wide normalization.")
    good_names = [channel_labels[index] for index in good_indices]
    include = np.ones((len(good_indices), fit_indices.size), dtype=bool)

    def exclude_interval(onset, duration, label, channels=("ALL",)):
        if not str(label).startswith("BAD_"):
            return
        time_mask = (fit_times >= float(onset)) & (fit_times < float(onset) + float(duration))
        if not time_mask.any():
            return
        channel_set = {str(channel) for channel in (channels or ["ALL"])}
        if str(label) != "BAD_channel" or "ALL" in channel_set:
            include[:, time_mask] = False
            return
        for local_index, name in enumerate(good_names):
            if name in channel_set:
                include[local_index, time_mask] = False

    # Imported MNE annotations represent all-channel BAD intervals.
    for onset, duration, label in zip(review["master"].annotations.onset, review["master"].annotations.duration, review["master"].annotations.description):
        exclude_interval(onset, duration, label)
    # GUI annotations retain channel specificity.
    for annotation in STEP4_MANUAL_ANNOTATIONS:
        exclude_interval(annotation["time_sec"], annotation.get("duration_sec", 0), annotation["label"], annotation.get("channels", ["ALL"]))
    # Imported display markers can also contain channel-specific BAD_channel data.
    for marker in eeg_display.get("markers", []):
        exclude_interval(marker["time_sec"], marker.get("duration_sec", 0), marker["label"], marker.get("channels", ["ALL"]))

    selected_values = values[good_indices]
    preliminary = selected_values[include]
    preliminary = preliminary[np.isfinite(preliminary)]
    if preliminary.size == 0:
        raise ValueError("No good channel-samples remain after BAD exclusions.")
    center = float(np.nanmedian(preliminary))
    robust_sd = 1.4826 * float(np.nanmedian(np.abs(preliminary - center)))
    automatic_rejected = np.zeros(fit_indices.size, dtype=bool)
    if np.isfinite(robust_sd) and robust_sd > 0:
        masked_scores = np.where(include, np.abs((selected_values - center) / robust_sd), np.nan)
        point_score = np.nanpercentile(masked_scores, 75.0, axis=0)
        automatic_rejected = np.isfinite(point_score) & (point_score > threshold)
        include[:, automatic_rejected] = False
    fit = selected_values[include]
    fit = fit[np.isfinite(fit)]
    if fit.size == 0:
        raise ValueError("No channel-samples remain after robust-z exclusion.")
    globals()["STEP4_RECORDING_WIDE_THREE_Z_REJECTED"] = int(automatic_rejected.sum())
    globals()["STEP4_RECORDING_WIDE_THREE_Z_FIT_SAMPLES"] = int(fit.size)
    globals()["STEP4_RECORDING_WIDE_SCALE_SAMPLE_STEP_SEC"] = 1.0
    return float(np.nanmean(fit)), float(np.nanstd(fit)), len(good_indices), int(fit.size)


@step4_app.callback(
    Output("bad-channel-status", "children"),
    Output("eeg-graph", "figure", allow_duplicate=True),
    Input("set-bad-channels", "n_clicks"),
    Input("clear-bad-channels", "n_clicks"),
    State("bad-channel-scope", "value"),
    State("bad-channel-selection", "value"),
    prevent_initial_call=True,
)
def update_step4_bad_channels(set_clicks, clear_clicks, scope, selected_channels):
    global STEP4_RECORDING_SCALE
    if ctx.triggered_id == "clear-bad-channels":
        review["master"].info["bads"] = []
        message = "Cleared global bad-channel designations."
    else:
        selected_channels = list(selected_channels or [])
        if not selected_channels:
            return "Select at least one channel first.", no_update
        if scope == "global":
            review["master"].info["bads"] = selected_channels
            message = "Global bad channels: " + ", ".join(selected_channels)
        else:
            if STEP4_FOCUSED_INTERVAL is None:
                return "Focus an interval before marking interval-specific bad channels.", no_update
            STEP4_MANUAL_ANNOTATIONS.append({
                "time_sec": float(STEP4_FOCUSED_INTERVAL["start_sec"]),
                "duration_sec": float(STEP4_FOCUSED_INTERVAL["end_sec"] - STEP4_FOCUSED_INTERVAL["start_sec"]),
                "label": "BAD_channel", "channels": selected_channels,
            })
            message = "Marked " + ", ".join(selected_channels) + " as bad in the focused interval."
    if STEP4_DISPLAY_MODE == "global z-score":
        try:
            mean, std, _, _ = recording_wide_global_scale(3.0)
            STEP4_RECORDING_SCALE = (mean, std)
            set_adaptive_display_window(STEP4_VIEW_START_MINUTE, STEP4_VIEW_END_MINUTE)
            message += " Global z-score preview was recomputed."
        except Exception as error:
            message += f" Could not recompute preview: {error}"
    return message, build_interactive_eeg_figure()

@step4_app.callback(
    Output("eeg-graph", "figure", allow_duplicate=True),
    Output("zscore-preview-status", "children"),
    Input("preview-zscore", "n_clicks"),
    Input("show-average-reference", "n_clicks"),
    State("high-variance-threshold", "value"),
    prevent_initial_call=True,
)
def preview_step4_display(zscore_clicks, average_clicks, threshold):
    global STEP4_DISPLAY_MODE, STEP4_RECORDING_SCALE
    if ctx.triggered_id == "preview-zscore":
        try:
            mean, std, fit_channels, fit_points = recording_wide_global_scale(threshold or 3.0)
            if not np.isfinite(std) or std <= 0:
                raise ValueError("invalid global standard deviation")
            STEP4_RECORDING_SCALE = (mean, std)
            STEP4_DISPLAY_MODE = "global z-score"
            set_adaptive_display_window(STEP4_VIEW_START_MINUTE, STEP4_VIEW_END_MINUTE)
            return build_interactive_eeg_figure(), f"Previewing global z-score: mean={mean:.3e} V, SD={std:.3e} V; fit={fit_channels} good channels and {fit_points:,} one-second samples."
        except Exception as error:
            return no_update, f"Unable to compute global z-score: {error}"
    STEP4_DISPLAY_MODE = "average-referenced µV"
    set_adaptive_display_window(STEP4_VIEW_START_MINUTE, STEP4_VIEW_END_MINUTE)
    return build_interactive_eeg_figure(), "Previewing average-referenced EEG (µV)."

@step4_app.callback(
    Output("eeg-graph", "figure", allow_duplicate=True),
    Output("action-status", "children", allow_duplicate=True),
    Output("toggle-full-rate-view", "children"),
    Input("toggle-full-rate-view", "n_clicks"),
    State("eeg-graph", "relayoutData"),
    prevent_initial_call=True,
)
def toggle_step4_250hz_view(clicks, relayout_data):
    global STEP4_HIGH_RES_ACTIVE, display_samples, time_minutes, data_to_plot, DISPLAY_AMPLITUDE_LIMIT_UV, CHANNEL_SPACING, offsets
    start_minute, end_minute = STEP4_VIEW_START_MINUTE, STEP4_VIEW_END_MINUTE
    relayout_data = relayout_data or {}
    if "xaxis.range[0]" in relayout_data and "xaxis.range[1]" in relayout_data:
        start_minute = float(relayout_data["xaxis.range[0]"])
        end_minute = float(relayout_data["xaxis.range[1]"])
    elif isinstance(relayout_data.get("xaxis.range"), (list, tuple)) and len(relayout_data["xaxis.range"]) == 2:
        start_minute, end_minute = map(float, relayout_data["xaxis.range"])
    if start_minute is None or end_minute is None or end_minute <= start_minute:
        return no_update, f"Zoom to a non-zero interval first, then switch to {sampling_rate:g} Hz view.", f"Switch to {sampling_rate:g} Hz view"
    STEP4_VIEW_START_MINUTE, STEP4_VIEW_END_MINUTE = start_minute, end_minute
    if STEP4_HIGH_RES_ACTIVE:
        STEP4_HIGH_RES_ACTIVE = False
        set_adaptive_display_window(start_minute, end_minute)
        return build_interactive_eeg_figure(), "Returned to overview sampling for this same interval.", f"Switch to {sampling_rate:g} Hz view"
    start = max(0, int(np.floor(start_minute * 60.0 * sampling_rate)))
    stop = min(number_samples, int(np.ceil(end_minute * 60.0 * sampling_rate)))
    display_samples = np.arange(start, stop, dtype=int)
    time_minutes = display_samples / sampling_rate / 60.0
    if STEP4_DISPLAY_MODE == "global z-score" and STEP4_RECORDING_SCALE is not None:
        mean, std = STEP4_RECORDING_SCALE
        data_to_plot = ((data_filtered[:, display_samples] - mean) / std).astype(np.float32, copy=False)
        DISPLAY_AMPLITUDE_LIMIT_UV = max(3.0, float(np.nanpercentile(np.abs(data_to_plot), 98.0)))
    else:
        data_to_plot = data_filtered[:, display_samples].astype(np.float32, copy=False) * 1e6
        DISPLAY_AMPLITUDE_LIMIT_UV = max(1.0, float(np.nanpercentile(np.abs(data_to_plot), 98.0)))
    data_to_plot = np.clip(data_to_plot, -DISPLAY_AMPLITUDE_LIMIT_UV, DISPLAY_AMPLITUDE_LIMIT_UV)
    CHANNEL_SPACING = 2.5 * DISPLAY_AMPLITUDE_LIMIT_UV
    offsets = np.arange(number_channels)[::-1] * CHANNEL_SPACING
    STEP4_HIGH_RES_ACTIVE = True
    return build_interactive_eeg_figure(), f"Displaying {end_minute - start_minute:.2f} minutes at full {sampling_rate:g} Hz ({display_samples.size:,} samples).", "Return to overview sampling"

@step4_app.callback(
    Output("eeg-graph", "figure", allow_duplicate=True),
    Output("package-status", "children"),
    Output("replace-existing-context", "value"),
    Input("confirm-package-interval", "n_clicks"),
    State("package-participant", "value"),
    State("package-reviewer", "value"),
    State("processing-section-context", "value"),
    State("replace-existing-context", "value"),
    State("high-variance-threshold", "value"),
    prevent_initial_call=True,
)
def confirm_and_package_interval(clicks, participant, reviewer, context, replace_existing, robust_z_threshold):
    global STEP4_VIEW_START_MINUTE, STEP4_VIEW_END_MINUTE, STEP4_FOCUSED_INTERVAL
    global data_to_plot, DISPLAY_AMPLITUDE_LIMIT_UV, CHANNEL_SPACING, offsets, STEP4_DISPLAY_MODE
    try:
        output, used_all_samples_for_scale = _package_focused_interval(participant, reviewer, str(context), allow_replace="replace" in (replace_existing or []), robust_z_threshold=robust_z_threshold or 3.0)
    except Exception as error:
        return no_update, f"Not packaged: {error}", no_update
    STEP4_VIEW_START_MINUTE = None
    STEP4_VIEW_END_MINUTE = None
    STEP4_FOCUSED_INTERVAL = None
    data_to_plot = PHYSICAL_DATA_TO_PLOT.copy()
    DISPLAY_AMPLITUDE_LIMIT_UV = float(np.nanpercentile(np.abs(data_to_plot), 98.0)) or 1.0
    CHANNEL_SPACING = 2.5 * DISPLAY_AMPLITUDE_LIMIT_UV
    offsets = np.arange(number_channels)[::-1] * CHANNEL_SPACING
    STEP4_DISPLAY_MODE = "average-referenced µV"
    STEP4_PROCESSING_SEGMENTS[:] = []
    scale_note = " All time samples were used for scaling because the interval is entirely marked BAD; globally and interval-specific bad channels were still excluded." if used_all_samples_for_scale else ""
    replaced_note = " Replaced the previous context." if "replace" in (replace_existing or []) else ""
    return build_interactive_eeg_figure(), f"Added {context} to {output.name}.{replaced_note} Returned to full recording; select the next interval.{scale_note}", []


# ---------------------------------------------------------
# Capture interval or point selections.
# ---------------------------------------------------------

@step4_app.callback(
    Output(
        "start-minutes",
        "value",
    ),
    Output(
        "end-minutes",
        "value",
    ),
    Output(
        "selection-status",
        "children",
    ),
    Input(
        "eeg-graph",
        "selectedData",
    ),
    Input(
        "eeg-graph",
        "clickData",
    ),
    Input(
        "annotation-kind",
        "value",
    ),
    prevent_initial_call=True,
)
def capture_plot_selection(
    selected_data,
    click_data,
    annotation_kind,
):

    if annotation_kind == "interval":

        if not selected_data:

            return (
                no_update,
                no_update,
                (
                    "Drag a box over the "
                    "desired interval."
                ),
            )

        # Plotly normally provides the exact
        # box-selection x-axis range.
        selected_range = selected_data.get(
            "range",
            {},
        ).get(
            "x",
        )

        if selected_range:

            start_minute = float(
                min(selected_range)
            )

            end_minute = float(
                max(selected_range)
            )

        else:

            points = selected_data.get(
                "points",
                [],
            )

            if not points:

                return (
                    no_update,
                    no_update,
                    "No EEG points selected.",
                )

            selected_times = [
                float(point["x"])
                for point in points
            ]

            start_minute = min(
                selected_times
            )

            end_minute = max(
                selected_times
            )

        start_minute = round(
            start_minute,
            4,
        )

        end_minute = round(
            end_minute,
            4,
        )

        duration_minute = round(
            end_minute - start_minute,
            4,
        )

        return (
            start_minute,
            end_minute,
            (
                f"Selected interval: "
                f"{start_minute:.4f}–"
                f"{end_minute:.4f} minutes "
                f"(duration "
                f"{duration_minute:.4f} min)"
            ),
        )

    # Point-event mode.
    if not click_data:

        return (
            no_update,
            no_update,
            "Click the desired event time.",
        )

    clicked_minute = float(
        click_data["points"][0]["x"]
    )

    onset_minute = round(
        clicked_minute,
        4,
    )

    return (
        onset_minute,
        onset_minute,
        (
            f"Selected point: "
            f"{onset_minute:.4f} minutes"
        ),
    )


# ---------------------------------------------------------
# Add and undo annotations.
# ---------------------------------------------------------

@step4_app.callback(
    Output(
        "eeg-graph",
        "figure",
    ),
    Output(
        "manual-annotation-table",
        "data",
    ),
    Output(
        "action-status",
        "children",
    ),
    Input(
        "add-annotation",
        "n_clicks",
    ),
    Input(
        "undo-annotation",
        "n_clicks",
    ),
    Input("decrease-display-gain", "n_clicks"),
    Input("increase-display-gain", "n_clicks"),
    Input("reset-display-gain", "n_clicks"),
    Input("focus-selected-interval", "n_clicks"),
    Input("show-full-recording", "n_clicks"),
    Input("clear-focus-selection", "n_clicks"),
    State(
        "annotation-kind",
        "value",
    ),
    State(
        "standard-label",
        "value",
    ),
    State(
        "affected-channels",
        "value",
    ),
    State(
        "start-minutes",
        "value",
    ),
    State(
        "end-minutes",
        "value",
    ),
    State("eeg-graph", "relayoutData"),
    prevent_initial_call=True,
)
def modify_manual_annotations(
    add_clicks,
    undo_clicks,
    decrease_gain_clicks,
    increase_gain_clicks,
    reset_gain_clicks,
    focus_clicks,
    show_full_clicks,
    clear_focus_clicks,
    annotation_kind,
    standard_label,
    affected_channels,
    start_minute,
    end_minute,
    relayout_data,
):

    global STEP4_DISPLAY_GAIN, STEP4_VIEW_START_MINUTE, STEP4_VIEW_END_MINUTE, STEP4_FOCUSED_INTERVAL, STEP4_DISPLAY_MODE, STEP4_HIGH_RES_ACTIVE
    triggered = ctx.triggered_id

    if triggered == "focus-selected-interval":
        if start_minute is None or end_minute is None or float(end_minute) <= float(start_minute):
            return no_update, no_update, "Select a non-zero interval before focusing it."
        STEP4_VIEW_START_MINUTE = float(start_minute)
        STEP4_VIEW_END_MINUTE = float(end_minute)
        STEP4_FOCUSED_INTERVAL = {
            "start_sec": STEP4_VIEW_START_MINUTE * 60.0,
            "end_sec": STEP4_VIEW_END_MINUTE * 60.0,
        }
        set_adaptive_display_window(STEP4_VIEW_START_MINUTE, STEP4_VIEW_END_MINUTE)
        return build_interactive_eeg_figure(), no_update, (
            f"Focused view: {STEP4_VIEW_START_MINUTE:.4f}–{STEP4_VIEW_END_MINUTE:.4f} minutes."
        )
    if triggered == "show-full-recording":
        STEP4_VIEW_START_MINUTE = None
        STEP4_VIEW_END_MINUTE = None
        set_adaptive_display_window()
        return build_interactive_eeg_figure(), no_update, "Showing the full recording overview."

    if triggered == "clear-focus-selection":
        STEP4_FOCUSED_INTERVAL = None
        return no_update, no_update, "Focused interval cleared. Packaging will use the whole recording unless you focus a new interval."

    # Plotly reports an ordinary zoom through relayoutData.  Preserve it before
    # rebuilding the figure for a gain change instead of falling back to full view.
    relayout_data = relayout_data or {}
    if "xaxis.range[0]" in relayout_data and "xaxis.range[1]" in relayout_data:
        STEP4_VIEW_START_MINUTE = float(relayout_data["xaxis.range[0]"])
        STEP4_VIEW_END_MINUTE = float(relayout_data["xaxis.range[1]"])
    if triggered == "decrease-display-gain":
        STEP4_DISPLAY_GAIN = max(0.01, STEP4_DISPLAY_GAIN / 2.0)
        return build_interactive_eeg_figure(), no_update, f"Display gain: {STEP4_DISPLAY_GAIN:.2f}×"
    if triggered == "increase-display-gain":
        STEP4_DISPLAY_GAIN = STEP4_DISPLAY_GAIN * 2.0
        return build_interactive_eeg_figure(), no_update, f"Display gain: {STEP4_DISPLAY_GAIN:.2f}×"
    if triggered == "reset-display-gain":
        STEP4_DISPLAY_GAIN = 1.0
        STEP4_HIGH_RES_ACTIVE = False
        STEP4_VIEW_START_MINUTE = None
        STEP4_VIEW_END_MINUTE = None
        STEP4_DISPLAY_MODE = "average-referenced µV"
        set_adaptive_display_window()
        return build_interactive_eeg_figure(), no_update, "Display reset: full average-referenced recording at 1.00× gain."

    if triggered == "undo-annotation":

        if STEP4_MANUAL_ANNOTATIONS:

            removed = (
                STEP4_MANUAL_ANNOTATIONS.pop()
            )

            status = (
                "Removed last annotation: "
                f"{removed['label']}"
            )

        else:

            status = (
                "There are no new "
                "annotations to undo."
            )

    elif triggered == "add-annotation":

        if start_minute is None:

            return (
                no_update,
                no_update,
                "Select a time first.",
            )

        if not affected_channels:

            return (
                no_update,
                no_update,
                "Select ALL or affected channels.",
            )

        start_minute = float(
            start_minute
        )

        if annotation_kind == "interval":

            if end_minute is None:

                return (
                    no_update,
                    no_update,
                    "Select an interval end time.",
                )

            end_minute = float(
                end_minute
            )

            if end_minute <= start_minute:

                return (
                    no_update,
                    no_update,
                    (
                        "Interval end must be "
                        "after interval start."
                    ),
                )

            duration_minute = (
                end_minute - start_minute
            )

        else:

            duration_minute = 0.0

        # MNE and the saved HDF5 use seconds internally.
        # Only the Step 4 entry boxes use minutes.
        start_sec = start_minute * 60.0
        duration_sec = duration_minute * 60.0

        if "ALL" in affected_channels:

            saved_channels = ["ALL"]

        else:

            saved_channels = list(
                affected_channels
            )

        annotation = {
            "time_sec": round(
                start_sec,
                3,
            ),
            "duration_sec": round(
                duration_sec,
                3,
            ),
            "label": str(
                standard_label
            ),
            "channels": saved_channels,
        }

        STEP4_MANUAL_ANNOTATIONS.append(
            annotation
        )

        status = (
            f"Added {standard_label} "
            f"at {start_minute:.4f} minutes."
        )

    else:

        return (
            no_update,
            no_update,
            no_update,
        )

    table_rows = []

    for annotation in (
        STEP4_MANUAL_ANNOTATIONS
    ):

        table_rows.append(
            {
                "time_sec": (
                    annotation["time_sec"]
                ),
                "duration_sec": (
                    annotation[
                        "duration_sec"
                    ]
                ),
                "label": annotation["label"],
                "channels_text": ",".join(
                    annotation["channels"]
                ),
            }
        )

    return (
        build_interactive_eeg_figure(),
        table_rows,
        status,
    )


# ---------------------------------------------------------
# Add and remove processing sections selected in the graph.
# ---------------------------------------------------------

@step4_app.callback(
    Output("processing-section-table", "data"),
    Output("processing-section-status", "children"),
    Input("add-processing-section", "n_clicks"),
    Input("undo-processing-section", "n_clicks"),
    State("processing-section-context", "value"),
    State("start-minutes", "value"),
    State("end-minutes", "value"),
    prevent_initial_call=True,
)
def modify_processing_sections(add_clicks, undo_clicks, context, start_minute, end_minute):
    triggered = ctx.triggered_id
    if triggered == "undo-processing-section":
        if STEP4_PROCESSING_SEGMENTS:
            removed = STEP4_PROCESSING_SEGMENTS.pop()
            status = f"Cleared {removed['context']} selected interval."
        else:
            status = "There are no processing sections to undo."
    else:
        if start_minute is None or end_minute is None:
            return no_update, "Select an interval in the graph before adding a processing section."
        start_sec = round(float(start_minute) * 60.0, 3)
        end_sec = round(float(end_minute) * 60.0, 3)
        if end_sec <= start_sec:
            return no_update, "A processing section needs a non-zero interval."
        # One Step 5 export is one reviewed interval. Replacing the prior
        # selection lets the reviewer correct the choice without reloading Step 4.
        STEP4_PROCESSING_SEGMENTS[:] = []
        STEP4_PROCESSING_SEGMENTS.append({
            "context": str(context),
            "start_sec": start_sec,
            "end_sec": end_sec,
            "duration_sec": round(end_sec - start_sec, 3),
        })
        status = f"Selected {context}: {start_sec:.3f}–{end_sec:.3f} sec for Step 5."
    return list(STEP4_PROCESSING_SEGMENTS), status



# ---------------------------------------------------------
# Find an available local port and launch the browser app without blocking the notebook.
# ---------------------------------------------------------

def stop_step4_dashboard():
    """Stop the local Step 4 server when the review moves to Step 5."""
    server = globals().get("STEP4_DASH_SERVER")
    if server is not None:
        server.shutdown()
        server.server_close()
        globals()["STEP4_DASH_SERVER"] = None


stop_step4_dashboard()

with socket.socket() as port_socket:

    port_socket.bind(
        ("127.0.0.1", 0)
    )

    STEP4_DASH_PORT = int(
        port_socket.getsockname()[1]
    )

STEP4_DASH_URL = (
    f"http://127.0.0.1:"
    f"{STEP4_DASH_PORT}"
)

print(
    "Starting interactive EEG annotation interface:"
)

print(
    STEP4_DASH_URL
)

# Open the browser shortly after the server begins.
threading.Timer(1.2, lambda: webbrowser.open(STEP4_DASH_URL)).start()

STEP4_DASH_SERVER = make_server(
    "127.0.0.1",
    STEP4_DASH_PORT,
    step4_app.server,
    threaded=True,
)
STEP4_DASH_THREAD = threading.Thread(
    target=STEP4_DASH_SERVER.serve_forever,
    daemon=True,
)
STEP4_DASH_THREAD.start()

print(
    "Step 4 is running in the browser and this cell is complete. "
    "Keep the notebook kernel running; Step 5 will stop the local server."
)
# Out:
# Display filtering: 0.5 to 50.0 Hz
# Starting interactive EEG annotation interface:
# http://127.0.0.1:64452
# Step 4 is running in the browser and this cell is complete. Keep the notebook kernel running; Step 5 will stop the local server.
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/dash/deps/polyfill@7.v4_4_1m1787961781.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/dash/deps/react@18.v4_4_1m1787961781.3.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/dash/deps/react-dom@18.v4_4_1m1787961781.3.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/dash/deps/prop-types@15.v4_4_1m1787961781.8.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v4_4_1m1787961781.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/dash/dcc/dash_core_components.v4_4_1m1787961781.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v4_4_1m1787961781.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/dash/html/dash_html_components.v4_4_1m1787961781.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/dash/dash_table/bundle.v7_4_1m1787961781.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_favicon.ico?v=4.4.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/dash/dash_table/async-highlight.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/plotly/package_data/plotly.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:06] "GET /_dash-component-suites/dash/dash_table/async-table.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:42] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:45] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:18:51] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:19:20] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:19:29] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:19:39] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:19:51] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:19:57] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:20:01] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:20:10] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:20:17] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:20:23] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:20:29] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:20:39] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Sep/2026 14:20:43] "POST /_dash-update-component?endId=TXjjEmSeDHsRWHGTvloPI5vD~f256c9585501d8bac58257c7e903980e129e60092c0d9f0b83d1d33cbe0b65df HTTP/1.1" 200 -
